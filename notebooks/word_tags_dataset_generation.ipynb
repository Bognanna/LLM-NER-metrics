# %%
import os

# %%
path_original = "..//data//external//cadec//original"
dir_list_original = os.listdir(path_original)
dir_list_original = sorted(dir_list_original, key = lambda x: (x.split('.')[0], int(x.split('.')[1])))
len(dir_list_original)
# Out:
# 1250

# %%
path_text = "..//data//external//cadec//text"
dir_list_text = os.listdir(path_text)
dir_list_text = sorted(dir_list_text, key = lambda x: (x.split('.')[0], int(x.split('.')[1])))
len(dir_list_text)
# Out:
# 1250

# %%
import pandas as pd

def process_original_to_df(path):
    cadec_df = pd.read_csv(path, sep='\t', names=['tag_number', 'entity_type_offsets', 'text'])
    cadec_df["entity_type"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(0)        # Get only entity type from entity_type_offsets
    cadec_df["offsets"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(1)            # Get only offsets from entity_type_offsets
    cadec_df = cadec_df.drop("entity_type_offsets", axis=1)                                 # Rename column
    cadec_df = cadec_df[ -cadec_df.tag_number.str.startswith('#')]                          # Remove annotation notes
    cadec_df = cadec_df.reset_index(drop=True)                                              # Reset index

    return cadec_df

# %%
FILE = 'ARTHROTEC.6'
PATH_ORIGINAL = f'..\\data\\external\\cadec\\original\\{FILE}.ann'
PATH_TEXT = f'..\\data\\external\\cadec\\text\\{FILE}.txt'

cadec_df = pd.read_csv(PATH_ORIGINAL, sep='\t', names=['tag_number', 'entity_type_offsets', 'text'])
cadec_df["entity_type"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(0)        # Get only entity type from entity_type_offsets
cadec_df["offsets"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(1)            # Get only offsets from entity_type_offsets
cadec_df = cadec_df.drop("entity_type_offsets", axis=1)                                 # Rename column
cadec_df = cadec_df[ -cadec_df.tag_number.str.startswith('#')]                          # Remove annotation notes
cadec_df = cadec_df.reset_index(drop=True)                                              # Reset index
cadec_df.head(5)
# Out:
#   tag_number                       text entity_type          offsets
# 0         T1               stomach pain         ADR            14 26
# 1         T2              slight nausea         ADR            32 45
# 2         T3                     reflux         ADR            52 58
# 3         T6  abdominal cramps and pain         ADR  152 161;166 181
# 4         T4              abdominal gas         ADR  152 161;162 165

# %%
def create_list_of_entities(df):
    entities = []
    offsets = str(df.iloc[3]['offsets']).split(';')

    for id in range(df.shape[0]):
        offsets = str(df.iloc[id]['offsets']).split(';')
        
        for o in offsets:
            start = int(o.split(' ')[0])
            end = int(o.split(' ')[1])
            entities.append(
                {
                    "type": {
                        "tag": df.iloc[id]['entity_type'], 
                        "tag number": df.iloc[id]['tag_number']
                        },
                    "start": start,
                    "end": end,
                }
            )

    return sorted(entities, key=lambda d: (d['start'], d['end']))

# %%
entities = []
offsets = str(cadec_df.iloc[3]['offsets']).split(';')

for id in range(cadec_df.shape[0]):
    offsets = str(cadec_df.iloc[id]['offsets']).split(';')
    
    for o in offsets:
        start = int(o.split(' ')[0])
        end = int(o.split(' ')[1])
        entities.append(
            {
                "type": {
                    "tag": cadec_df.iloc[id]['entity_type'], 
                    "tag number": cadec_df.iloc[id]['tag_number']
                    },
                "start": start,
                "end": end,
           }
        )


entities = sorted(entities, key=lambda d: (d['start'], d['end']))

# %%
def create_datataset_of_word_tags(path, entities):
    
    words = []

    with open(path) as f:

        word_start = 0
        char_pos = 0
        word = ""
        labels = []
        
        while True:
            char = f.read(1)
        
            if not char:
                break

            if not (char.isalpha() or char.isdigit() or char == '\''):
                if word:

                    if not (word[0].isalpha() or word[0].isdigit()):
                        word = word[1:]

                    for entity in entities:
                        if (
                            word_start >= entity["start"]
                            and char_pos <= entity["end"]
                        ):
                            
                            labels.append(entity["type"])

                    words.append(
                        {
                            "word": word,
                            "start": word_start,
                            "end": char_pos,
                            "label": labels
                        }
                    )

                    word = "" 
                    labels = []

                word_start = char_pos + 1

            word += char
            char_pos += 1

        f.close()

    return words

# %%
words = []

with open(PATH_TEXT) as f:

    word_start = 0
    char_pos = 0
    word = ""
    labels = []
    
    while True:
        char = f.read(1)
      
        if not char:
            break

        if not (char.isalpha() or char.isdigit() or char == '\''):
            if word:

                if not (word[0].isalpha() or word[0].isdigit()):
                    word = word[1:]

                for entity in entities:
                    if (
                        word_start >= entity["start"]
                        and char_pos <= entity["end"]
                    ):
                        
                        labels.append(entity["type"])

                words.append(
                    {
                        "word": word,
                        "start": word_start,
                        "end": char_pos,
                        "label": labels
                    }
                )

                word = "" 
                labels = []

            word_start = char_pos + 1

        word += char
        char_pos += 1

    f.close()

# %%
for word in words[30:40]:
    print(word)
# Out:
# {'word': 'abdominal', 'start': 152, 'end': 161, 'label': [{'tag': 'ADR', 'tag number': 'T6'}, {'tag': 'ADR', 'tag number': 'T4'}]}
# {'word': 'gas', 'start': 162, 'end': 165, 'label': [{'tag': 'ADR', 'tag number': 'T4'}]}
# {'word': 'cramps', 'start': 166, 'end': 172, 'label': [{'tag': 'ADR', 'tag number': 'T6'}]}
# {'word': 'and', 'start': 173, 'end': 176, 'label': [{'tag': 'ADR', 'tag number': 'T6'}]}
# {'word': 'pain', 'start': 177, 'end': 181, 'label': [{'tag': 'ADR', 'tag number': 'T6'}]}
# {'word': 'would', 'start': 182, 'end': 187, 'label': []}
# {'word': 'be', 'start': 188, 'end': 190, 'label': []}
# {'word': 'with', 'start': 191, 'end': 195, 'label': []}
# {'word': 'me', 'start': 196, 'end': 198, 'label': []}
# {'word': 'all', 'start': 199, 'end': 202, 'label': []}

# %%
for file_original, file_text in zip(dir_list_original, dir_list_text):
    path_original = f'..\\data\\external\\cadec\\original\\{file_original}'
    path_text = f'..\\data\\external\\cadec\\text\\{file_text}'

    try:
        df_original = process_original_to_df(path_original)
        print(df_original)
        entities = create_list_of_entities(df_original)
        create_datataset_of_word_tags(path_text, entities)
# Out:
#   tag_number                   text entity_type  offsets
# 0         T1             bit drowsy         ADR     9 19
# 1         T2  little blurred vision         ADR    29 50
# 2         T3              Arthrotec        Drug   93 102
# 3         T5              arthritis     Disease  179 188
# 4         T6                  agony     Symptom  260 265
# 5         T4       gastric problems         ADR    62 78
# 6         T7                  pains     Symptom  412 417
# 7         T8       feel a bit weird         ADR  437 453
#   tag_number                                          text entity_type  \
# 0         T1                                          pain     Symptom
# 1         T2                                     heartburn         ADR
# 2         T3                                        nausea         ADR
# 3         T4                              voracious hunger         ADR
# 4         T5  sharp unbearable cramping pains in lower gut         ADR
# 5         T6                           pain in my forearms     Symptom
#
#    offsets
# 0  153 157
# 1      0 9
# 2    11 17
# 3    40 56
# 4   59 103
# 5  234 253
#    tag_number                              text entity_type          offsets
# 0          T1                      Constipation         ADR             0 12
# 1          T2                        joint pain         ADR            62 72
# 2          T3                              Pain         ADR          121 125
# 3          T4  extreme itching on legs and arms         ADR          173 205
# 4          T5            mobility has DECREASED         ADR          238 260
# 5          T6                      constipation         ADR          344 356
# 6          T7                         Arthrotec        Drug          414 423
# 7          T8                              pain     Symptom          448 452
# 8         T10                       muscle pain         ADR  509 515;522 526
# 9         T15                        joint pain         ADR  516 521;522 526
# 10        T11                        co-codamol        Drug          583 593
#   tag_number                                            text entity_type  \
# 0         T1                                       arthrotec        Drug
# 1         T2  menstruating with heavy bleeding every 11 days         ADR
# 2         T4                                 horrific cramps         ADR
# 3         T5                                       arthrotec        Drug
# 4         T6                                            pain     Symptom
# 5         T8                                   endometriosis     Disease
#
#    offsets
# 0  194 203
# 1     5 51
# 2  140 155
# 3  303 312
# 4  335 339
# 5  227 240
#   tag_number       text entity_type  offsets
# 0         T1  arthritis     Disease  305 314
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[95], line 7
#       5 df_original = process_original_to_df(path_original)
#       6 print(df_original)
# ----> 7 entities = create_list_of_entities(df_original)
#       8 create_datataset_of_word_tags(path_text, entities)
#
# Cell In[85], line 3, in create_list_of_entities(df)
#       1 def create_list_of_entities(df):
#       2     entities = []
# ----> 3     offsets = str(df.iloc[3]['offsets']).split(';')
#       5     for id in range(df.shape[0]):
#       6         offsets = str(df.iloc[id]['offsets']).split(';')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
import json

def save_to_jsonl(data, file_path):
    with open(file_path, 'w+') as f:
        for entry in data:
            f.write(json.dumps(entry) + '\n')

# %%
for file_original, file_text in zip(dir_list_original, dir_list_text):
    path_original = f'..\\data\\external\\cadec\\original\\{file_original}'
    path_text = f'..\\data\\external\\cadec\\text\\{file_text}'

    try:
        df_original = process_original_to_df(path_original)
        print(file_original)
        entities = create_list_of_entities(df_original)
        word_tags = create_datataset_of_word_tags(path_text, entities)

        output_json_file_path = f'..\\data\\processed\\word tags format\\{file_text}.jsonl'

        save_to_jsonl(word_tags, output_json_file_path)
    except IndexError as e:
        print(e)
# Out:
# ARTHROTEC.1.ann
# ARTHROTEC.2.ann
# ARTHROTEC.3.ann
# ARTHROTEC.4.ann
# ARTHROTEC.5.ann
# single positional indexer is out-of-bounds
# ARTHROTEC
ann
# single positional indexer is out-of-bounds
# ARTHROTEC.129.ann
# ARTHROTEC.130.ann
# ARTHROTEC.131.ann
# ARTHROTEC.132.ann
# ARTHROTEC.133.ann
# ARTHROTEC.134.ann
# ARTHROTEC.135.ann
# ARTHROTEC.136.ann
# ARTHROTEC.137.ann
# ARTHROTEC.138.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.139.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.140.ann
# ARTHROTEC.141.ann
# ARTHROTEC.142.ann
# ARTHROTEC.143.ann
# ARTHROTEC.144.ann
# ARTHROTEC.145.ann
# single positional indexer is out-of-bounds
# CAMBIA.1.ann
# single positional indexer is out-of-bounds
# CAMBIA.2.ann
# single positional indexer is out-of-bounds
# CAMBIA.3.ann
# CAMBIA.4.ann
# single positional indexer is out-of-bounds
# CATAFLAM.1.ann
# single positional indexer is out-of-bounds
# CATAFLAM.2.ann
# CATAFLAM.3.ann
# CATAFLAM.4.ann
# CATAFLAM.5.ann
# single positional indexer is out-of-bounds
# CATAFLAM.6.ann
# single positional indexer is out-of-bounds
# CATAFLAM.7.ann
# CATAFLAM.8.ann
# CATAFLAM.9.ann
# CATAFLAM.10.ann
# DICLOFENAC-POTASSIUM.1.ann
# single positional indexer is out-of-bounds
# DICLOFENAC-POTASSIUM.2.ann
# single positional indexer is out-of-bounds
# DICLOFENAC-POTASSIUM.3.ann
# DICLOFENAC-SODIUM.1.ann
# DICLOFENAC-SODIUM.2.ann
# DICLOFENAC-SODIUM.3.ann
# DICLOFENAC-SODIUM.4.ann
# single positional indexer is out-of-bounds
# DICLOFENAC-SODIUM.5.ann
# DICLOFENAC-SODIUM.6.ann
# DICLOFENAC-SODIUM.7.ann
# FLECTOR.1.ann
# LIPITOR.1.ann
# LIPITOR.2.ann
# single positional indexer is out-of-bounds
# LIPITOR.3.ann
# LIPITOR.4.ann
# single positional indexer is out-of-bounds
# LIPITOR.5.ann
# single positional indexer is out-of-bounds
# LIPITOR.6.ann
# LIPITOR.7.ann
# LIPITOR.8.ann
# LIPITOR.9.ann
# LIPITOR.10.ann
# LIPITOR.11.ann
# LIPITOR.12.ann
# LIPITOR.13.ann
# LIPITOR.14.ann
# LIPITOR.15.ann
# LIPITOR.16.ann
# single positional indexer is out-of-bounds
# LIPITOR.17.ann
# LIPITOR.18.ann
# LIPITOR.19.ann
# single positional indexer is out-of-bounds
# LIPITOR.20.ann
# LIPITOR.21.ann
# LIPITOR.22.ann
# single positional indexer is out-of-bounds
# LIPITOR.23.ann
# LIPITOR.24.ann
# LIPITOR.25.ann
# LIPITOR.26.ann
# single positional indexer is out-of-bounds
# LIPITOR.27.ann
# LIPITOR.28.ann
# single positional indexer is out-of-bounds
# LIPITOR.29.ann
# LIPITOR.30.ann
# single positional indexer is out-of-bounds
# LIPITOR.31.ann
# LIPITOR.32.ann
# LIPITOR.33.ann
# LIPITOR.34.ann
# LIPITOR.35.ann
# LIPITOR.36.ann
# LIPITOR.37.ann
# single positional indexer is out-of-bounds
# LIPITOR.38.ann
# LIPITOR.39.ann
# LIPITOR.40.ann
# single positional indexer is out-of-bounds
# LIPITOR.41.ann
# LIPITOR.585.ann
# LIPITOR.586.ann
# LIPITOR.587.ann
# LIPITOR.588.ann
# LIPITOR.589.ann
# LIPITOR.590.ann
# LIPITOR.591.ann
# LIPITOR.592.ann
# LIPITOR.593.ann
# LIPITOR.594.ann
# single positional indexer is out-of-bounds
# LIPITOR.595.ann
# LIPITOR.596.ann
# LIPITOR.597.ann
# single positional indexer is out-of-bounds
# LIPITOR.598.ann
# LIPITOR.599.ann
# single positional indexer is out-of-bounds
# LIPITOR.600.ann
# single positional indexer is out-of-bounds
# LIPITOR.601.ann
# single positional indexer is out-of-bounds
# LIPITOR.602.ann
# LIPITOR.603.ann
# LIPITOR.604.ann
# LIPITOR.605.ann
# LIPITOR.606.ann
# LIPITOR.607.ann
# single positional indexer is out-of-bounds
# LIPITOR.608.ann
# single positional indexer is out-of-bounds
# LIPITOR.609.ann
# single positional indexer is out-of-bounds
# LIPITOR.610.ann
# LIPITOR.611.ann
# LIPITOR.612.ann
# LIPITOR.613.ann
# LIPITOR.614.ann
# LIPITOR.615.ann
# single positional indexer is out-of-bounds
# LIPITOR.616.ann
# LIPITOR.617.ann
# LIPITOR.618.ann
# single positional indexer is out-of-bounds
# LIPITOR.619.ann
# LIPITOR.620.ann
# LIPITOR.621.ann
# LIPITOR.622.ann
# LIPITOR.623.ann
# LIPITOR.624.ann
# single positional indexer is out-of-bounds
# LIPITOR.625.ann
# single positional indexer is out-of-bounds
# LIPITOR.626.ann
# LIPITOR.627.ann
# LIPITOR.628.ann
# single positional indexer is out-of-bounds
# LIPITOR.629.ann
# LIPITOR.630.ann
# single positional indexer is out-of-bounds
# LIPITOR.631.ann
# LIPITOR.632.ann
# single positional indexer is out-of-bounds
# LIPITOR.633.ann
# single positional indexer is out-of-bounds
# LIPITOR.634.ann
# single positional indexer is out-of-bounds
# LIPITOR.635.ann
# LIPITOR.636.ann
# single positional indexer is out-of-bounds
# LIPITOR.637.ann
# single positional indexer is out-of-bounds
# LIPITOR.638.ann
# single positional indexer is out-of-bounds
# LIPITOR.639.ann
# LIPITOR.640.ann
# LIPITOR.641.ann
# LIPITOR.642.ann
# LIPITOR.643.ann
# LIPITOR.644.ann
# single positional indexer is out-of-bounds
# LIPITOR.645.ann
# single positional indexer is out-of-bounds
# LIPITOR.646.ann
# LIPITOR.647.ann
# single positional indexer is out-of-bounds
# LIPITOR.648.ann
# LIPITOR.649.ann
# single positional indexer is out-of-bounds
# LIPITOR.650.ann
# LIPITOR.651.ann
# single positional indexer is out-of-bounds
# LIPITOR.652.ann
# LIPITOR.653.ann
# LIPITOR.654.ann
# LIPITOR.655.ann
# single positional indexer is out-of-bounds
# LIPITOR.656.ann
# LIPITOR.657.ann
# single positional indexer is out-of-bounds
# LIPITOR.658.ann
# LIPITOR.659.ann
# LIPITOR.660.ann
# LIPITOR.661.ann
# LIPITOR.662.ann
# LIPITOR.663.ann
# LIPITOR.664.ann
# single positional indexer is out-of-bounds
# LIPITOR.665.ann
# LIPITOR.666.ann
# LIPITOR.667.ann
# single positional indexer is out-of-bounds
# LIPITOR.847.ann
# LIPITOR.848.ann
# LIPITOR.849.ann
# LIPITOR.850.ann
# LIPITOR.851.ann
# LIPITOR.852.ann
# single positional indexer is out-of-bounds
# LIPITOR.853.ann
# LIPITOR.854.ann
# LIPITOR.855.ann
# single positional indexer is out-of-bounds
# LIPITOR.856.ann
# LIPITOR.857.ann
# single positional indexer is out-of-bounds
# LIPITOR.858.ann
# LIPITOR.859.ann
# LIPITOR.860.ann
# LIPITOR.861.ann
# LIPITOR.862.ann
# single positional indexer is out-of-bounds
# LIPITOR.863.ann
# single positional indexer is out-of-bounds
# LIPITOR.864.ann
# single positional indexer is out-of-bounds
# LIPITOR.865.ann
# LIPITOR.866.ann
# LIPITOR.867.ann
# LIPITOR.868.ann
# LIPITOR.869.ann
# single positional indexer is out-of-bounds
# LIPITOR.870.ann
# LIPITOR.871.ann
# single positional indexer is out-of-bounds
# LIPITOR.872.ann
# LIPITOR.873.ann
# LIPITOR.874.ann
# LIPITOR.875.ann
# LIPITOR.876.ann
# single positional indexer is out-of-bounds
# LIPITOR.877.ann
# single positional indexer is out-of-bounds
# LIPITOR.878.ann
# LIPITOR.879.ann
# single positional indexer is out-of-bounds
# LIPITOR.880.ann
# single positional indexer is out-of-bounds
# LIPITOR.881.ann
# single positional indexer is out-of-bounds
# LIPITOR.882.ann
# LIPITOR.883.ann
# single positional indexer is out-of-bounds
# LIPITOR.884.ann
# LIPITOR.885.ann
# LIPITOR.886.ann
# LIPITOR.887.ann
# LIPITOR.888.ann
# LIPITOR.889.ann
# single positional indexer is out-of-bounds
# LIPITOR.890.ann
# LIPITOR.891.ann
# LIPITOR.892.ann
# single positional indexer is out-of-bounds
# LIPITOR.893.ann
# LIPITOR.894.ann
# LIPITOR.895.ann
# single positional indexer is out-of-bounds
# LIPITOR.896.ann
# LIPITOR.897.ann
# LIPITOR.898.ann
# LIPITOR.899.ann
# LIPITOR.900.ann
# single positional indexer is out-of-bounds
# LIPITOR.901.ann
# LIPITOR.902.ann
# LIPITOR.903.ann
# LIPITOR.904.ann
# LIPITOR.905.ann
# LIPITOR.906.ann
# LIPITOR.907.ann
# single positional indexer is out-of-bounds
# LIPITOR.908.ann
# LIPITOR.909.ann
# LIPITOR.910.ann
# single positional indexer is out-of-bounds
# LIPITOR.911.ann
# LIPITOR.912.ann
# LIPITOR.913.ann
# LIPITOR.914.ann
# LIPITOR.915.ann
# single positional indexer is out-of-bounds
# LIPITOR.916.ann
# LIPITOR.917.ann
# LIPITOR.918.ann
# single positional indexer is out-of-bounds
# LIPITOR.919.ann
# single positional indexer is out-of-bounds
# LIPITOR.920.ann
# LIPITOR.921.ann
# single positional indexer is out-of-bounds
# LIPITOR.922.ann
# LIPITOR.923.ann
# LIPITOR.924.ann
# single positional indexer is out-of-bounds
# LIPITOR.925.ann
# LIPITOR.926.ann
# LIPITOR.927.ann
# LIPITOR.928.ann
# LIPITOR.929.ann
# single positional indexer is out-of-bounds
# LIPITOR.930.ann
# single positional indexer is out-of-bounds
# LIPITOR.931.ann
# LIPITOR.932.ann
# LIPITOR.933.ann
# single positional indexer is out-of-bounds
# LIPITOR.934.ann
# LIPITOR.935.ann
# LIPITOR.936.ann
# LIPITOR.937.ann
# LIPITOR.938.ann
# single positional indexer is out-of-bounds
# LIPITOR.939.ann
# LIPITOR.940.ann
# single positional indexer is out-of-bounds
# LIPITOR.941.ann
# LIPITOR.942.ann
# single positional indexer is out-of-bounds
# LIPITOR.943.ann
# LIPITOR.944.ann
# LIPITOR.945.ann
# LIPITOR.946.ann
# single positional indexer is out-of-bounds
# LIPITOR.947.ann
# LIPITOR.948.ann
# single positional indexer is out-of-bounds
# LIPITOR.949.ann
# single positional indexer is out-of-bounds
# LIPITOR.950.ann
# LIPITOR.951.ann
# LIPITOR.952.ann
# LIPITOR.953.ann
# single positional indexer is out-of-bounds
# LIPITOR.954.ann
# LIPITOR.955.ann
# LIPITOR.956.ann
# LIPITOR.957.ann
# LIPITOR.958.ann
# single positional indexer is out-of-bounds
# LIPITOR.959.ann
# LIPITOR.960.ann
# single positional indexer is out-of-bounds
# LIPITOR.961.ann
# LIPITOR.962.ann
# single positional indexer is out-of-bounds
# LIPITOR.963.ann
# single positional indexer is out-of-bounds
# LIPITOR.964.ann
# single positional indexer is out-of-bounds
# LIPITOR.965.ann
# LIPITOR.966.ann
# LIPITOR.967.ann
# LIPITOR.968.ann
# LIPITOR.969.ann
# LIPITOR.970.ann
# LIPITOR.971.ann
# LIPITOR.972.ann
# LIPITOR.973.ann
# LIPITOR.974.ann
# LIPITOR.975.ann
# LIPITOR.976.ann
# LIPITOR.977.ann
# LIPITOR.978.ann
# LIPITOR.979.ann
# LIPITOR.980.ann
# LIPITOR.981.ann
# LIPITOR.982.ann
# LIPITOR.983.ann
# LIPITOR.984.ann
# LIPITOR.985.ann
# single positional indexer is out-of-bounds
# LIPITOR.986.ann
# single positional indexer is out-of-bounds
# LIPITOR.987.ann
# LIPITOR.988.ann
# single positional indexer is out-of-bounds
# LIPITOR.989.ann
# LIPITOR.990.ann
# LIPITOR.991.ann
# LIPITOR.992.ann
# LIPITOR.993.ann
# single positional indexer is out-of-bounds
# LIPITOR.994.ann
# LIPITOR.995.ann
# LIPITOR.996.ann
# LIPITOR.997.ann
# LIPITOR.998.ann
# single positional indexer is out-of-bounds
# LIPITOR.999.ann
# single positional indexer is out-of-bounds
# LIPITOR.1000.ann
# PENNSAID.1.ann
# PENNSAID.2.ann
# single positional indexer is out-of-bounds
# PENNSAID.3.ann
# PENNSAID.4.ann
# single positional indexer is out-of-bounds
# SOLARAZE.1.ann
# single positional indexer is out-of-bounds
# SOLARAZE.2.ann
# SOLARAZE.3.ann
# single positional indexer is out-of-bounds
# VOLTAREN.1.ann
# single positional indexer is out-of-bounds
# VOLTAREN.2.ann
# single positional indexer is out-of-bounds
# VOLTAREN.3.ann
# VOLTAREN.4.ann
# VOLTAREN.5.ann
# VOLTAREN.6.ann
# VOLTAREN.7.ann
# VOLTAREN.8.ann
# VOLTAREN.9.ann
# VOLTAREN.10.ann
# single positional indexer is out-of-bounds
# VOLTAREN.11.ann
# VOLTAREN.12.ann
# VOLTAREN.13.ann
# VOLTAREN.14.ann
# single positional indexer is out-of-bounds
# VOLTAREN.15.ann
# single positional indexer is out-of-bounds
# VOLTAREN.16.ann
# single positional indexer is out-of-bounds
# VOLTAREN.17.ann
# VOLTAREN.18.ann
# VOLTAREN.19.ann
# single positional indexer is out-of-bounds
# VOLTAREN.20.ann
# VOLTAREN.21.ann
# VOLTAREN.22.ann
# single positional indexer is out-of-bounds
# VOLTAREN.23.ann
# VOLTAREN.24.ann
# single positional indexer is out-of-bounds
# VOLTAREN.25.ann
# VOLTAREN.26.ann
# single positional indexer is out-of-bounds
# VOLTAREN.27.ann
# single positional indexer is out-of-bounds
# VOLTAREN.28.ann
# single positional indexer is out-of-bounds
# VOLTAREN.29.ann
# single positional indexer is out-of-bounds
# VOLTAREN.30.ann
# VOLTAREN.31.ann
# single positional indexer is out-of-bounds
# VOLTAREN.32.ann
# single positional indexer is out-of-bounds
# VOLTAREN.33.ann
# single positional indexer is out-of-bounds
# VOLTAREN.34.ann
# VOLTAREN.35.ann
# single positional indexer is out-of-bounds
# VOLTAREN.36.ann
# VOLTAREN.37.ann
# single positional indexer is out-of-bounds
# VOLTAREN.38.ann
# single positional indexer is out-of-bounds
# VOLTAREN.39.ann
# single positional indexer is out-of-bounds
# VOLTAREN.40.ann
# VOLTAREN.41.ann
# single positional indexer is out-of-bounds
# VOLTAREN.42.ann
# single positional indexer is out-of-bounds
# VOLTAREN.43.ann
# single positional indexer is out-of-bounds
# VOLTAREN.44.ann
# VOLTAREN.45.ann
# VOLTAREN.46.ann
# VOLTAREN-XR.1.ann
# VOLTAREN-XR.2.ann
# VOLTAREN-XR.3.ann
# VOLTAREN-XR.4.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.5.ann
# VOLTAREN-XR.6.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.7.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.8.ann
# VOLTAREN-XR.9.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.10.ann
# VOLTAREN-XR.11.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.12.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.13.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.14.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.15.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.16.ann
# VOLTAREN-XR.17.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.18.ann
# VOLTAREN-XR.19.ann
# VOLTAREN-XR.20.ann
# VOLTAREN-XR.21.ann
# VOLTAREN-XR.22.ann
# ZIPSOR.1.ann
# single positional indexer is out-of-bounds
# ZIPSOR.2.ann
# single positional indexer is out-of-bounds
# ZIPSOR.3.ann
# single positional indexer is out-of-bounds
# ZIPSOR.4.ann
# single positional indexer is out-of-bounds
# ZIPSOR.5.ann
