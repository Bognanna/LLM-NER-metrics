# %%
import os

# %%
path_original = "..//data//external//cadec//original"
dir_list_original = os.listdir(path_original)
dir_list_original = sorted(dir_list_original, key = lambda x: (x.split('.')[0], int(x.split('.')[1])))
len(dir_list_original)
# Out:
# 1250

# %%
path_text = "..//data//external//cadec//text"
dir_list_text = os.listdir(path_text)
dir_list_text = sorted(dir_list_text, key = lambda x: (x.split('.')[0], int(x.split('.')[1])))
len(dir_list_text)
# Out:
# 1250

# %%
import pandas as pd

def process_original_to_df(path):
    cadec_df = pd.read_csv(path, sep='\t', names=['tag_number', 'entity_type_offsets', 'text'])
    cadec_df["entity_type"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(0)        # Get only entity type from entity_type_offsets
    cadec_df["offsets"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(1)            # Get only offsets from entity_type_offsets
    cadec_df = cadec_df.drop("entity_type_offsets", axis=1)                                 # Rename column
    cadec_df = cadec_df[ -cadec_df.tag_number.str.startswith('#')]                          # Remove annotation notes
    cadec_df = cadec_df.reset_index(drop=True)                                              # Reset index

    return cadec_df

# %%
FILE = 'ARTHROTEC.6'
PATH_ORIGINAL = f'..\\data\\external\\cadec\\original\\{FILE}.ann'
PATH_TEXT = f'..\\data\\external\\cadec\\text\\{FILE}.txt'

cadec_df = pd.read_csv(PATH_ORIGINAL, sep='\t', names=['tag_number', 'entity_type_offsets', 'text'])
cadec_df["entity_type"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(0)        # Get only entity type from entity_type_offsets
cadec_df["offsets"] = cadec_df.entity_type_offsets.str.split(n=1).str.get(1)            # Get only offsets from entity_type_offsets
cadec_df = cadec_df.drop("entity_type_offsets", axis=1)                                 # Rename column
cadec_df = cadec_df[ -cadec_df.tag_number.str.startswith('#')]                          # Remove annotation notes
cadec_df = cadec_df.reset_index(drop=True)                                              # Reset index
cadec_df.head(5)
# Out:
#   tag_number                       text entity_type          offsets
# 0         T1               stomach pain         ADR            14 26
# 1         T2              slight nausea         ADR            32 45
# 2         T3                     reflux         ADR            52 58
# 3         T6  abdominal cramps and pain         ADR  152 161;166 181
# 4         T4              abdominal gas         ADR  152 161;162 165

# %%
def create_list_of_entities(df):
    entities = []
    offsets = str(df.iloc[3]['offsets']).split(';')

    for id in range(df.shape[0]):
        offsets = str(df.iloc[id]['offsets']).split(';')
        
        for o in offsets:
            start = int(o.split(' ')[0])
            end = int(o.split(' ')[1])
            entities.append(
                {
                    "type": {
                        "tag": df.iloc[id]['entity_type'], 
                        "tag number": df.iloc[id]['tag_number']
                        },
                    "start": start,
                    "end": end,
                }
            )

    return sorted(entities, key=lambda d: (d['start'], d['end']))

# %%
entities = []
offsets = str(cadec_df.iloc[3]['offsets']).split(';')

for id in range(cadec_df.shape[0]):
    offsets = str(cadec_df.iloc[id]['offsets']).split(';')
    
    for o in offsets:
        start = int(o.split(' ')[0])
        end = int(o.split(' ')[1])
        entities.append(
            {
                "type": {
                    "tag": cadec_df.iloc[id]['entity_type'], 
                    "tag number": cadec_df.iloc[id]['tag_number']
                    },
                "start": start,
                "end": end,
           }
        )


entities = sorted(entities, key=lambda d: (d['start'], d['end']))

# %%
def create_datataset_of_word_tags(path, entities):
    
    words = []

    with open(path) as f:

        word_start = 0
        char_pos = 0
        word = ""
        labels = []
        
        while True:
            char = f.read(1)
        
            if not char:
                break

            if not (char.isalpha() or char.isdigit() or char == '\''):
                if word:

                    if not (word[0].isalpha() or word[0].isdigit()):
                        word = word[1:]

                    for entity in entities:
                        if (
                            word_start >= entity["start"]
                            and char_pos <= entity["end"]
                        ):
                            
                            labels.append(entity["type"])
                    if word_start != char_pos:
                        words.append(
                            {
                                "word": word,
                                "start": word_start,
                                "end": char_pos,
                                "label": labels
                            }
                        )

                    word = "" 
                    labels = []

                word_start = char_pos + 1

            word += char
            char_pos += 1

        f.close()

    return words

# %%
words = []

with open(PATH_TEXT) as f:

    word_start = 0
    char_pos = 0
    word = ""
    labels = []
    
    while True:
        char = f.read(1)
      
        if not char:
            break

        if not (char.isalpha() or char.isdigit() or char == '\''):
            if word:

                if not (word[0].isalpha() or word[0].isdigit()):
                    word = word[1:]

                for entity in entities:
                    if (
                        word_start >= entity["start"]
                        and char_pos <= entity["end"]
                    ):
                        
                        labels.append(entity["type"])

                if word_start != char_pos:
                    words.append(
                        {
                            "word": word,
                            "start": word_start,
                            "end": char_pos,
                            "label": labels
                        }
                    )

                word = "" 
                labels = []

            word_start = char_pos + 1

        word += char
        char_pos += 1

    f.close()

# %%
for word in words[30:40]:
    print(word)
# Out:
# {'word': 'cramps', 'start': 166, 'end': 172, 'label': [{'tag': 'ADR', 'tag number': 'T6'}]}
# {'word': 'and', 'start': 173, 'end': 176, 'label': [{'tag': 'ADR', 'tag number': 'T6'}]}
# {'word': 'pain', 'start': 177, 'end': 181, 'label': [{'tag': 'ADR', 'tag number': 'T6'}]}
# {'word': 'would', 'start': 182, 'end': 187, 'label': []}
# {'word': 'be', 'start': 188, 'end': 190, 'label': []}
# {'word': 'with', 'start': 191, 'end': 195, 'label': []}
# {'word': 'me', 'start': 196, 'end': 198, 'label': []}
# {'word': 'all', 'start': 199, 'end': 202, 'label': []}
# {'word': 'day', 'start': 203, 'end': 206, 'label': []}
# {'word': 'I', 'start': 208, 'end': 209, 'label': []}

# %%
for file_original, file_text in zip(dir_list_original, dir_list_text):
    path_original = f'..\\data\\external\\cadec\\original\\{file_original}'
    path_text = f'..\\data\\external\\cadec\\text\\{file_text}'

    try:
        df_original = process_original_to_df(path_original)
        print(df_original)
        entities = create_list_of_entities(df_original)
        create_datataset_of_word_tags(path_text, entities)
    except IndexError as e:
        print(f'{e}')
# Out:
#   tag_number                   text entity_type  offsets
# 0         T1             bit drowsy         ADR     9 19
# 1         T2  little blurred vision         ADR    29 50
# 2         T3              Arthrotec        Drug   93 102
# 3         T5              arthritis     Disease  179 188
# 4         T6                  agony     Symptom  260 265
# 5         T4       gastric problems         ADR    62 78
# 6         T7                  pains     Symptom  412 417
# 7         T8       feel a bit weird         ADR  437 453
#   tag_number                                          text entity_type  \
# 0         T1                                          pain     Symptom
# 1         T2                                     heartburn         ADR
# 2         T3                                        nausea         ADR
# 3         T4                              voracious hunger         ADR
# 4         T5  sharp unbearable cramping pains in lower gut         ADR
# 5         T6                           pain in my forearms     Symptom
#
#    offsets
# 0  153 157
# 1      0 9
# 2    11 17
# 3    40 56
# 4   59 103
# 5  234 253
#    tag_number                              text entity_type          offsets
# 0          T1                      Constipation         ADR             0 12
# 1          T2                        joint pain         ADR            62 72
# 2          T3                              Pain         ADR          121 125
# 3          T4  extreme itching on legs and arms         ADR          173 205
# 4          T5            mobility has DECREASED         ADR          238 260
# 5          T6                      constipation         ADR          344 356
# 6          T7                         Arthrotec        Drug          414 423
# 7          T8                              pain     Symptom          448 452
# 8         T10                       muscle pain         ADR  509 515;522 526
# 9         T15                        joint pain         ADR  516 521;522 526
# 10        T11                        co-codamol        Drug          583 593
#   tag_number                                            text entity_type  \
# 0         T1                                       arthrotec        Drug
# 1         T2  menstruating with heavy bleeding every 11 days         ADR
# 2         T4                                 horrific cramps         ADR
# 3         T5                                       arthrotec        Drug
# 4         T6                                            pain     Symptom
# 5         T8                                   endometriosis     Disease
#
#    offsets
# 0  194 203
# 1     5 51
# 2  140 155
# 3  303 312
# 4  335 339
# 5  227 240
#   tag_number       text entity_type  offsets
# 0         T1  arthritis     Disease  305 314
# single positional indexer is out-of-bounds
#    tag_number                       text entity_type          offsets
# 0          T1               stomach pain         ADR            14 26
# 1          T2              slight nausea         ADR            32 45
# 2          T3                     reflux         ADR            52 58
# 3          T6  abdominal cramps and pain         ADR  152 161;166 181
# 4          T4              abdominal gas         ADR  152 161;162 165
# 5          T8           abdominal cramps         ADR          228 244
# 6          T9                  Arthrotec        Drug          290 299
# 7         T10                       pain     Symptom          321 325
# 8         T11                     reflux     Finding          434 440
# 9         T13           abdominal cramps         ADR  466 475;480 486
# 10        T17       abdominal discomfort         ADR  466 475;491 501
# 11        T12              abdominal gas         ADR  466 475;476 479
# 12        T14                  Arthrotec        Drug          567 576
# 13        T15                    Tylenol        Drug          589 596
# 14        T16                  Arthrotec        Drug          680 689
#   tag_number                                              text entity_type  \
# 0         T1  severe sudden onset headache in the back of head         ADR
# 1         T2                                         clonidine        Drug
# 2         T3                            BP was extrememly high         ADR
# 3         T4                                    pulse was high         ADR
# 4         T5                                           high BP         ADR
# 5         T6                     pulse is still extremely high         ADR
# 6         T7                                       tachycardia         ADR
#
#    offsets
# 0    17 65
# 1  168 177
# 2   91 113
# 3  119 133
# 4  226 233
# 5  295 324
# 6  548 559
#   tag_number                          text entity_type  offsets
# 0         T1  starting to upset my stomach         ADR    33 61
# 1         T2                          pain     Symptom  169 173
# 2         T3                   can't sleep     Symptom  137 148
# single positional indexer is out-of-bounds
#   tag_number                 text entity_type  offsets
# 0         T1       EXTREME nausea         ADR  497 511
# 1         T2            vomitting         ADR      0 9
# 2         T3                 sick         ADR  109 113
# 3         T4             sickness         ADR  188 196
# 4         T5  very painful joints     Symptom  320 339
# 5         T6             sickness         ADR  289 297
# 6        T10                 pain     Symptom  368 372
#   tag_number                           text entity_type       offsets
# 0         T1                       hip pain     Symptom       121 129
# 1         T2  walk up & down steps sideways     Symptom  55 75;96 104
# 2         T3                   Hunger pangs         ADR          0 12
# single positional indexer is out-of-bounds
#   tag_number       text entity_type  offsets
# 0         T1  Arthrotec        Drug  158 167
# 1         T2       pain     Symptom  175 179
# single positional indexer is out-of-bounds
#   tag_number                                  text entity_type  offsets
# 0         T1                    severly restricted     Symptom  123 141
# 1         T2  could only walk less than 100 meters     Symptom  146 182
# 2         T3                   stomach sensitivity         ADR     5 24
# single positional indexer is out-of-bounds
#   tag_number                                         text entity_type  \
# 0         T1                                    gastritis         ADR
# 1         T2                         severe stomach upset         ADR
# 2         T3                           false full feeling         ADR
# 3         T4                           very poor appetite         ADR
# 4         T5                       increased menstruation         ADR
# 5         T6       menstrual cramps with vaginal bleeding         ADR
# 6         T9                             menopausal phase     Finding
# 7        T10  2-3 periods a month instead of once a month         ADR
# 8         T7    menstrual cramps without vaginal bleeding         ADR
#
#                    offsets
# 0                     6 15
# 1                    17 37
# 2                    59 77
# 3                    79 97
# 4                   99 121
# 5  168 184;193 197;209 225
# 6                  316 332
# 7                  123 166
# 8  168 184;201 208;209 225
#   tag_number                     text entity_type       offsets
# 0         T1              acid reflux         ADR       131 142
# 1         T2  acidic bile in my mouth         ADR       304 327
# 2         T4              pain severe     Symptom  80 84;94 100
# single positional indexer is out-of-bounds
#   tag_number               text entity_type  offsets
# 0         T1            diahrea         ADR    13 20
# 1         T2     ankle swelling         ADR  103 117
# 2         T3  lower tendon pain         ADR  122 139
# 3         T4               pain     Symptom  385 389
# 4         T5               pain     Symptom  320 324
# 5         T9           mobility     Symptom  336 344
#    tag_number                        text entity_type              offsets
# 0          T1                    headache         ADR              494 502
# 1          T2              abdominal pain     Symptom                80 94
# 2          T3             lower back pain     Symptom               96 111
# 3          T4                   Arthrotec        Drug              231 240
# 4          T5                   Arthrotec        Drug              568 577
# 5          T6      heavy vaginal bleeding         ADR              665 687
# 6          T8                       agony     Symptom                73 78
# 7          T9                        pain     Symptom              200 204
# 8         T10                        pain     Symptom              632 636
# 9         T11                 Paracetamol        Drug              255 266
# 10        T12                   Ibuprofen        Drug              341 350
# 11        T13                   Arthrotec        Drug              416 425
# 12        T14                 Paracetamol        Drug              432 443
# 13        T15                   Ibuprofen        Drug              517 526
# 14        T16                 Paracetamol        Drug              952 963
# 15        T18                  labor pain     Symptom              132 142
# 16        T19                        pain     Symptom              294 298
# 17        T20                serious pain     Symptom              867 879
# 18        T21    bleeding from the vagina     Symptom              888 912
# 19         T7  Diclofenac and Misoprostol        Drug  1000 1014;1022 1033
#    tag_number                                  text entity_type  \
# 0          T1                        abdominal pain         ADR
# 1          T2                     mentstrual cramps         ADR
# 2         T17                     diarreah cramping         ADR
# 3          T3                  lower abdominal pain         ADR
# 4          T9                                 Advil        Drug
# 5         T11       inflammation in my back muscles     Symptom
# 6          T4               inflammation in my neck     Symptom
# 7          T5                              GI bleed         ADR
# 8         T16              heavy menstrual bleeding         ADR
# 9         T15                                anemia         ADR
# 10        T10                         gastric bleed         ADR
# 11         T6                                 dizzy         ADR
# 12         T7                          light headed         ADR
# 13         T8  acidic bile at the back of my throat         ADR
#
#             offsets
# 0             74 88
# 1           100 117
# 2           118 135
# 3           221 241
# 4           312 317
# 5   331 349;359 371
# 6   331 349;350 354
# 7           400 408
# 8           477 501
# 9           576 582
# 10          594 607
# 11          674 679
# 12          684 696
# 13          711 747
#   tag_number                              text entity_type  offsets
# 0         T1                         arthrotec        Drug  208 217
# 1         T3                   highly immobile     Symptom  155 170
# 2         T4                     constant pain     Symptom  178 191
# 3         T5                              pain     Symptom  305 309
# 4         T6     chronic arthritic type issues     Disease  490 519
# 5         T7                    stomach issues     Symptom    79 93
# 6         T9  slightly heavier menstrual cycle         ADR     0 32
#   tag_number                            text entity_type  offsets
# 0         T1               lower pelvic pain         ADR    22 39
# 1         T2             Uterus contractions         ADR    41 60
# 2         T3                   Bloody vagina         ADR    62 75
# 3         T4                    gastric pain         ADR   99 111
# 4         T6  something wrong with my uterus     Symptom  204 234
#   tag_number                    text entity_type  offsets
# 0         T1               arthrotec        Drug    64 73
# 1         T2         lower back pain     Symptom    19 34
# 2         T3  MAJOR menstrual cramps         ADR  191 213
# 3         T4                bleeding         ADR  224 232
# 4         T5                sickness         ADR  249 257
# 5         T6                  puking         ADR  269 275
# 6         T7             menstrating         ADR  364 375
# 7         T8    brought my period on         ADR  414 434
# 8         T9                    pain         ADR  323 327
#   tag_number                    text entity_type          offsets
# 0         T1                  cramps         ADR            88 94
# 1         T2  heavy vaginal bleeding         ADR           99 121
# 2         T3          period another         ADR  126 132;175 182
# 3         T4                    pain     Symptom            17 21
#   tag_number                       text entity_type  offsets
# 0         T1  Severe abdominal cramping         ADR     0 25
# 1         T2                   sweating         ADR    27 35
# 2         T3              period cramps         ADR    37 50
# 3         T4           vaginal bleeding         ADR    52 68
# 4         T5                   diarrhea         ADR    70 78
# 5         T6                acid reflux         ADR    80 91
# 6         T7                   migraine     Finding  130 138
# 7         T8                       pain         ADR  148 152
# 8        T10                  dry mouth         ADR   93 102
#   tag_number                 text entity_type  offsets
# 0         T1   excessive cramping         ADR    53 71
# 1         T2                tired         ADR  153 158
# 2         T3              fatigue         ADR  159 166
# 3         T4  shortness of breath         ADR  167 186
# 4         T5                 pain         ADR  192 196
# 5         T6                dizzy         ADR  198 203
# 6         T7               nausea         ADR  204 210
# 7         T8         unconsolable         ADR  212 224
#   tag_number                   text entity_type          offsets
# 0         T2  severe vaginal cramps         ADR          112 133
# 1         T3                 cramps         ADR          260 266
# 2         T1                pamprin        Drug          268 275
# 3         T4              sore knee     Symptom          378 387
# 4         T5                 cramps         ADR          420 426
# 5        T10      knee inflammation     Symptom  486 490;496 508
# 6         T6              knee pain     Symptom  486 490;491 495
#   tag_number              text entity_type  offsets
# 0         T2  vaginal bleeding         ADR    52 68
# 1         T3            cramps         ADR    69 75
# 2         T4    abdominal pain         ADR    36 50
# 3         T5      stomach pain         ADR    22 34
# 4         T6            nausea         ADR      0 6
# 5         T7    extreme hunger         ADR     7 21
# 6         T1              pain     Symptom  262 266
#   tag_number             text entity_type          offsets
# 0         T1        arthrotec        Drug          235 244
# 1         T2        arthrotec        Drug          476 485
# 2         T3         diarrhea         ADR            60 68
# 3         T4           nausea         ADR            70 76
# 4         T5  loss of apetite         ADR            78 93
# 5         T6   stomach cramps         ADR           95 109
# 6         T7         arthotec        Drug          200 208
# 7         T8        back pain     Symptom          267 276
# 8         T9             pain     Symptom          505 509
# 9        T10  pain really bad     Symptom  572 576;582 592
#   tag_number                    text entity_type  offsets
# 0         T1               Arthrotec        Drug    22 31
# 1         T2  severe mentrual cramps         ADR    67 89
# 2         T3      birth control pill        Drug  103 121
# 3         T4                   Advil        Drug  230 235
# 4         T5               endo pain     Symptom  503 512
# 5         T6            so much pain         ADR  181 193
# 6         T9                abortion     Symptom  331 339
# 7        T11               menopause     Finding  444 453
#   tag_number              text entity_type  offsets
# 0         T1           Anxiety         ADR      0 7
# 1         T2   bleeding inside         ADR    30 45
# 2         T3             cramp         ADR    66 71
# 3         T4  'scared' feeling         ADR  117 133
# 4         T5              pain     Symptom  207 211
#    tag_number                          text entity_type  offsets
# 0          T1              vaginal bleeding         ADR     0 16
# 1          T2                      cramping         ADR    21 29
# 2          T3                    joint pain     Symptom    87 97
# 3          T4           return of my period         ADR  135 154
# 4          T5                          pain     Symptom  415 419
# 5          T6                      Cymbalta        Drug  369 377
# 6          T7                 endometriosis     Disease  183 196
# 7          T8                   adenomyosis     Disease  201 212
# 8          T9                           EDS     Disease  271 274
# 9         T10  impairment in blood clotting     Symptom  235 263
# 10        T12                     menopause     Finding    44 53
#    tag_number                            text entity_type    offsets
# 0          T1                       Arthrotec        Drug      15 24
# 1          T2                       back pain     Symptom    105 114
# 2          T3                vaginal bleeding         ADR    173 189
# 3          T4  clotting, and horrible periods         ADR    229 259
# 4          T5                       Arthrotec        Drug    478 487
# 5          T6                bleeding problem         ADR    688 704
# 6          T7             bleeding constantly         ADR    832 851
# 7          T9                            pain     Symptom    787 791
# 8         T11                   birth control        Drug    331 344
# 9         T12       bleeding has not subsided         ADR    355 380
# 10        T13    heavy/extra vaginal bleeding         ADR    616 644
# 11         T8                       Arthrotec        Drug  1029 1038
# 12        T10                        bleeding         ADR  1072 1080
# 13        T14                     extra pains     Symptom  1111 1122
#    tag_number                                  text entity_type  offsets
# 0          T1                             headaches         ADR      0 9
# 1          T2                     extreme tiredness         ADR    11 28
# 2          T4           heartburn in back of throat         ADR    36 63
# 3          T5                          hunger pangs         ADR    65 77
# 4          T6                             dry mouth         ADR    79 88
# 5          T7  severe lower abdominal pain/cramping         ADR   90 126
# 6          T8                        very irritable         ADR  128 142
# 7          T9                                  pain     Symptom  156 160
# 8         T10                          PMS symptoms         ADR  246 258
# 9         T11                                  GERD         ADR  341 345
# 10        T12                           misoprostol        Drug  311 322
#   tag_number                                               text entity_type  \
# 0         T1                              severe abdominal pain         ADR
# 1         T2  feeling like my stomach is full and empty at t...         ADR
# 2         T3                                            bruises         ADR
#
#    offsets
# 0    32 53
# 1  134 192
# 2  266 273
# single positional indexer is out-of-bounds
#   tag_number                     text entity_type          offsets
# 0         T1                    tired         ADR            22 27
# 1         T4  could not open my hands     Symptom  141 150;159 172
# 2         T2           could not walk     Symptom  141 150;151 155
# single positional indexer is out-of-bounds
#   tag_number                   text entity_type offsets
# 0         T1  Bleeding mini periods         ADR    0 21
# 1         T2            lightheaded         ADR   23 34
# 2         T3        finger tingling         ADR   46 61
# single positional indexer is out-of-bounds
#   tag_number                                               text entity_type  \
# 0         T1                                               pain     Symptom
# 1         T3                                             Nausea         ADR
# 2         T4                                 Irregular cramping         ADR
# 3         T5                                           hip pain     Symptom
# 4         T6                              period all month long         ADR
# 5         T7                                           nauseous         ADR
# 6         T8  bleeding several times a month menstrual cycle...         ADR
#
#           offsets
# 0           37 41
# 1         167 173
# 2         209 227
# 3         283 291
# 4         356 377
# 5         394 402
# 6  135 165;87 129
#   tag_number                    text entity_type  offsets
# 0         T1  sever abdominal cramps         ADR    62 84
# 1         T2           period cramps         ADR   96 109
# 2         T3                diarrhea         ADR  175 183
# 3         T4                   Advil        Drug  123 128
# 4         T6           cramping pain     Symptom  149 162
#   tag_number                       text entity_type  offsets
# 0         T1           massive diarrhea         ADR  188 204
# 1         T2  SEVERE abdominal cramping         ADR  157 182
# 2         T3            severe cramping         ADR  207 222
# 3         T4          chronic knee pain     Symptom  330 347
#    tag_number                   text entity_type  offsets
# 0          T1          Upset stomach         ADR     0 13
# 1          T2                 nausea         ADR    15 21
# 2          T3               vomiting         ADR    23 31
# 3          T4         abdominal pain         ADR    33 47
# 4          T5           constipation         ADR    49 61
# 5          T6           loose bowels         ADR    65 77
# 6          T7  excessive hot flashes         ADR   79 100
# 7          T8           night sweats         ADR  105 117
# 8          T9         blurred vision         ADR  119 133
# 9         T10       chest discomfort         ADR  149 165
# 10        T11             elbow pain     Symptom  289 299
# 11        T12           irritability         ADR  135 147
#   tag_number                text entity_type  offsets
# 0         T2           arthritis     Disease  104 113
# 1         T3           headaches     Finding  118 127
# 2         T4                pain     Finding  157 161
# 3         T5  vitamin C crystals        Drug  129 147
# 4         T6            migrains     Finding  215 223
#   tag_number                        text entity_type          offsets
# 0         T1                   Arthrotec        Drug            49 58
# 1         T2                chronic back     Symptom            69 81
# 2         T4  stomach trouble, or cramps     Finding          206 232
# 3         T6                    Celebrex        Drug          291 299
# 4         T7                       ulcer     Finding          331 336
# 5         T8                    Celebrex        Drug          364 372
# 6         T9             stomach trouble     Finding          400 415
# 7         T3               kidney damage     Finding  586 592;600 606
# 8        T12                liver damage     Finding  594 599;600 606
#    tag_number                                            text entity_type  \
# 0          T1                                          nausea         ADR
# 1          T2                                       Dizziness         ADR
# 2          T3                                        sickness         ADR
# 3          T4                                     stomach gas         ADR
# 4          T5                                    hunger pangs         ADR
# 5          T6                                    fibromyalgia     Disease
# 6          T7                                 severe hip pain     Symptom
# 7          T8                                   feel dreadful         ADR
# 8          T9                            fear of falling over         ADR
# 9         T10                                            sick         ADR
# 10        T11                                    light headed         ADR
# 11        T12                              permanent hangover         ADR
# 12        T13                                          hunger         ADR
# 13        T14                                 pain in my hips     Symptom
# 14        T15                                      co-codamol        Drug
# 15        T16                                      co codamol        Drug
# 16        T17                            cortozone injections        Drug
# 17        T18  feel like a bubble of air is stuck in my chest         ADR
# 18        T20                                 feel all clammy         ADR
#
#       offsets
# 0     807 813
# 1         0 9
# 2       11 19
# 3       21 32
# 4     145 157
# 5     311 323
# 6     403 418
# 7     660 673
# 8     731 751
# 9     760 764
# 10    769 781
# 11    879 897
# 12    916 922
# 13  1033 1048
# 14    293 303
# 15    443 453
# 16    566 586
# 17      34 80
# 18    833 848
#    tag_number                           text entity_type    offsets
# 0          T1                         nausea         ADR    110 116
# 1          T2                      dizziness         ADR    514 523
# 2          T3                         nausea         ADR    533 539
# 3          T4                  Stomach pains         ADR       0 13
# 4          T5                    chest pains         ADR      15 26
# 5          T6                        anxiety         ADR      28 35
# 6          T7                        fatigue         ADR      37 44
# 7          T8                       headache         ADR      46 54
# 8          T9             erratic heart beat         ADR      56 74
# 9         T10          raised blood pressure         ADR      76 97
# 10        T11                      dizziness         ADR     99 108
# 11        T12                 blurred vision         ADR    146 160
# 12        T13                      Arthrotec        Drug    191 200
# 13        T14                        Aciphex        Drug    229 236
# 14        T15             period like cramps         ADR    557 575
# 15        T16                         cramps         ADR    695 701
# 16        T17                    chest pains         ADR   995 1006
# 17        T18            elevated heart rate         ADR  1011 1030
# 18        T19                    hot flashes         ADR  1133 1144
# 19        T20                      dizziness         ADR  1146 1155
# 20        T21           sever stomach cramps         ADR  1157 1177
# 21        T22            weakness in my legs         ADR  1183 1202
# 22        T23                        Aciphex        Drug  1520 1527
# 23        T24                      Arthrotec        Drug  1532 1541
# 24        T25                     heart burn     Finding    347 357
# 25        T26                    indigestion     Finding    361 372
# 26        T27                    acid reflux     Finding    386 397
# 27        T31            thought I was dying         ADR  1216 1235
# 28        T35  inhibiting my menstrual cycle         ADR    722 751
#   tag_number                            text entity_type  offsets
# 0         T1                 severe cramping         ADR     7 22
# 1         T2                        diarrhea         ADR    24 32
# 2         T3  increased menstrual blood flow         ADR    34 64
# 3         T4                       Arthrotec        Drug    90 99
# 4         T5            urinary incontinence         ADR  124 144
#   tag_number             text entity_type  offsets
# 0         T1  SEVERE diarrhea         ADR  135 150
# 1         T2       heel spurs     Disease    30 40
# 2         T3          bad gas         ADR  123 130
# 3         T4   stomach cramps         ADR  162 176
# 4         T5           nausea         ADR  181 187
#   tag_number                                 text entity_type  offsets
# 0         T1   fluey feelings in upper arms, legs         ADR    53 90
# 1         T2                              flu jab        Drug  122 129
# 2         T3                              flu jab        Drug  205 212
# 3         T4                             Artrotec        Drug  263 271
# 4         T5                       fluey feelings         ADR  345 359
#   tag_number              text entity_type offsets
# 0         T1            Naseua         ADR     0 6
# 1         T2          vomiting         ADR    8 16
# 2         T3            cramps         ADR   18 24
# 3         T4  loss of appetite         ADR   36 52
# 4         T5          dry eyes         ADR   26 34
#   tag_number                              text entity_type  offsets
# 0         T1                    hunger feeling         ADR    32 46
# 1         T2                  stomach cramping         ADR    51 67
# 2         T3  muscle cramps in my calf muscles         ADR  111 143
# 3         T4                            cramps         ADR  207 213
# 4         T5                         arthritis     Disease  308 317
# 5         T7                    couldn't sleep         ADR  145 159
# 6         T9                    Charlie Horses     Symptom  522 536
#   tag_number                                   text entity_type  offsets
# 0         T1  walking up the stairs was intolerable     Symptom  145 182
# 1         T2                                   pain     Symptom  210 214
# single positional indexer is out-of-bounds
#   tag_number                  text entity_type      offsets
# 0         T1   intense pelvic pain         ADR  39 53;63 67
# 1         T2             back pain         ADR  58 62;63 67
# 2         T8           miscarriage     Finding        81 92
# 3         T9                  them     Finding      108 112
# 4         T6  intense, horrid pain         ADR      120 140
# 5         T3              spotting         ADR      170 178
# 6         T4     terrible bloating         ADR      184 201
# 7         T5                nausea         ADR      206 212
#   tag_number           text entity_type  offsets
# 0         T1           pain     Symptom    91 95
# 1         T3    hydrocodine        Drug  104 115
# 2         T2       bleeding         ADR  219 227
# 3         T5  stomach pains         ADR  231 244
# 4         T4  shoulder pain         ADR  317 330
#   tag_number                   text entity_type offsets
# 0         T1          severe nausea         ADR    0 13
# 1         T2              dizziness         ADR   14 23
# 2         T3  terrible stomach pain         ADR   24 45
# single positional indexer is out-of-bounds
#   tag_number                            text entity_type  offsets
# 0         T1                        Tmj pain     Symptom    24 32
# 1         T2                   period cramps         ADR  159 172
# 2         T3                       feel sick         ADR  258 267
# 3         T4  shooting lower abdominal pains         ADR  292 322
# 4         T8                 scared to death     Finding  328 343
#   tag_number                                   text entity_type  offsets
# 0         T1                              dizziness         ADR  243 252
# 1         T2                                   pain     Symptom    79 83
# 2         T3                  stiffness in my hands     Symptom  105 126
# 3         T4  very little mobility in my right hand     Symptom  145 182
# 4         T5                           extreme pain         ADR  211 223
# 5         T6                         heavy bleeding         ADR  224 238
#   tag_number       text entity_type offsets
# 0         T1  Arthrotec        Drug   48 57
# single positional indexer is out-of-bounds
#   tag_number       text entity_type  offsets
# 0         T1  occupycet        Drug    64 73
# 1         T2   bad back     Symptom   93 101
# 2         T3  knew pain     Symptom  106 115
# single positional indexer is out-of-bounds
#   tag_number            text entity_type  offsets
# 0         T1        diarrhea         ADR    47 55
# 1         T2        hip pain     Symptom    17 25
# 2         T3      bad cramps         ADR    36 46
# 3         T4  heavy bleeding         ADR    60 74
# 4         T5          cramps         ADR  192 198
# 5         T6    feeling sick         ADR  221 233
#   tag_number               text entity_type  offsets
# 0         T1           spotting         ADR     7 15
# 1         T2  spotting problems         ADR  123 140
# single positional indexer is out-of-bounds
#   tag_number                  text entity_type  offsets
# 0         T1             arthrotec        Drug  166 175
# 1         T2       Disorentatation         ADR     0 15
# 2         T3      trouble brathing         ADR    16 32
# 3         T4           extreme hot         ADR    34 45
# 4         T5  redness and swelling         ADR    47 67
# 5         T6               itching         ADR    69 76
# 6         T7       abominal cramps         ADR    84 99
# 7         T8             knee pain     Symptom  190 199
# 8         T9        cortisone shot        Drug  281 295
# 9        T10             knee pain     Symptom  303 312
#    tag_number                              text entity_type  offsets
# 0          T1                  vaginal bleeding         ADR     7 23
# 1          T2                       breast pain         ADR    62 73
# 2         T13  cycle was back (I'm menopausal )         ADR    28 60
# 3          T3                          erithema         ADR   97 105
# 4          T4                    skin is so dry         ADR  110 124
# 5          T5                    sweating a lot         ADR  162 176
# 6          T6                      pruritus ani         ADR  196 208
# 7          T7                          diarrhea         ADR  321 329
# 8          T8                              pain     Symptom  472 476
# 9          T9            first vaginal bleeding         ADR  488 510
# 10        T10                          pruritus         ADR  521 529
# 11        T11                  skin was all red         ADR  537 553
# 12        T12                         arthrotec        Drug  579 588
# 13        T14                        infections     Finding  667 677
# 14        T15                         Arthrotec        Drug  839 848
#   tag_number              text entity_type  offsets
# 0         T1      stomach pain         ADR    52 64
# 1         T2      bled heavily         ADR  105 117
# 2         T3          Bleeding         ADR  136 144
# 3         T4  rash on my wrist         ADR  200 216
# 4         T6          clotting         ADR  173 181
#   tag_number  text entity_type  offsets
# 0         T1   gas         ADR    30 33
# 1         T2  pain     Symptom  123 127
# single positional indexer is out-of-bounds
#   tag_number                                  text entity_type  offsets
# 0         T1                           stomich ake         ADR    16 27
# 1         T2                   shortness of breath         ADR    48 67
# 2         T3  mobility was going from bad to worse     Symptom  184 220
# 3         T4                       rematoid arthro     Disease  333 348
# 4         T5                            arthritice     Disease  524 534
# 5         T6                infection in her lungs     Disease  614 636
# 6         T7                             arthrotec        Drug  706 715
#    tag_number                                 text entity_type  offsets
# 0          T1                     vaginal bleeding         ADR     7 23
# 1          T2                          breast pain         ADR    62 73
# 2          T3                             erithema         ADR   98 106
# 3          T4                       skin is so dry         ADR  111 125
# 4          T5                         pruritus ani         ADR  197 209
# 5          T6                       sweating a lot         ADR  163 177
# 6          T7                             diarrhea         ADR  322 330
# 7          T8                                 pain     Symptom  473 477
# 8          T9                     vaginal bleeding         ADR  495 511
# 9         T10                             pruritus         ADR  522 530
# 10        T11                            arthrotec        Drug  580 589
# 11        T12                     skin was all red         ADR  538 554
# 12        T14  my cycle was back (I'm menopausal )         ADR    25 60
# 13        T13                            Arthrotec        Drug  840 849
#   tag_number                   text entity_type  offsets
# 0         T1              arthrotec        Drug  171 180
# 1         T2   extreme stomach pain         ADR    19 39
# 2         T3             drowsiness         ADR  136 146
# 3         T4              arthrotec        Drug  160 169
# 4         T5              knee pain     Symptom  204 213
# 5         T6           stomach pain         ADR  272 284
# 6         T7  moderate stomach pain         ADR    76 97
# 7         T8                  mobic        Drug  228 233
# 8         T9               celebrex        Drug  237 245
#   tag_number                         text entity_type  offsets
# 0         T1  gut-renching abdominal pain         ADR     8 35
# 1         T2                      diahrea         ADR    47 54
# 2         T3             vaginal bleeding         ADR    78 94
# 3         T4                 constipation         ADR  104 116
# 4         T5                     jaundins         ADR    37 45
# 5         T6                       sweats         ADR    56 62
# 6         T7                  hot flashes         ADR    65 76
#   tag_number           text entity_type offsets
# 0         T1  slight nausea         ADR   12 25
# single positional indexer is out-of-bounds
#   tag_number                         text entity_type  offsets
# 0         T1  crankiness and irritability         ADR    33 60
# 1         T2                 Increased BP         ADR    62 74
# 2         T3          visual disturbances         ADR   85 104
# 3         T4                         pain     Symptom  115 119
#   tag_number                      text entity_type          offsets
# 0         T1              light nausea         ADR          126 138
# 1         T2  sharp pain in my stomach         ADR          229 253
# 2         T3           pain unbearable         ADR  311 315;329 339
# 3         T4              stomach pain         ADR          395 407
# 4         T5               spinal pain     Symptom          472 483
# 5         T6              stomach pain         ADR          424 436
# 6         T7                  Naprosyn        Drug          562 570
#   tag_number      text entity_type  offsets
# 0         T1  diarrhea         ADR    11 19
# 1         T2       gas         ADR      5 8
# 2         T3      pain     Symptom  196 200
# single positional indexer is out-of-bounds
#   tag_number                text entity_type  offsets
# 0         T2  severe acid reflux         ADR     0 18
# 1         T1            headache         ADR  158 166
# single positional indexer is out-of-bounds
#   tag_number                     text entity_type            offsets
# 0         T1  severe uterine cramping         ADR  43 49;60 67;68 76
# 1         T2       heart palpitations         ADR            100 118
# 2         T3               Cold sweat         ADR              78 88
# 3         T4    severe colon cramping         ADR  43 49;50 55;68 76
# 4         T5                 fainting         ADR              90 98
#   tag_number                       text entity_type offsets
# 0         T1  frequent menstral periods         ADR    5 30
# single positional indexer is out-of-bounds
#   tag_number                                               text entity_type  \
# 0         T1  post-menopausal and have now had a six day period         ADR
# 1         T2                                     tender breasts         ADR
# 2         T3                                           bloating         ADR
# 3         T4                                           cramping         ADR
#
#        offsets
# 0  10 25;41 74
# 1      101 115
# 2      117 125
# 3      127 135
#   tag_number              text entity_type  offsets
# 0         T1      ARTHROTEC 50        Drug    84 96
# 1         T2  Gasto discomfort         ADR     7 23
# 2         T3            NEXIUM        Drug    42 48
# 3         T4         IB 800 mg        Drug  258 267
#   tag_number                                               text entity_type  \
# 0         T2  Vaginal bleeding when it was not time for my p...         ADR
# 1         T3                                          headaches         ADR
# 2         T4                                          neck pain         ADR
# 3         T5                                        weight gain         ADR
# 4         T6                                           bloating         ADR
# 5         T7                              pain in my lower back     Symptom
# 6         T1                                             Bextra        Drug
# 7         T8                                          Neurontin        Drug
# 8         T9                                              advil        Drug
#
#    offsets
# 0     0 51
# 1    53 62
# 2    64 73
# 3    87 98
# 4    74 82
# 5  122 143
# 6  263 269
# 7  273 282
# 8  313 318
#    tag_number                   text entity_type  offsets
# 0          T1               swelling         ADR      0 8
# 1          T2               bloating         ADR    10 18
# 2          T3     increased appetite         ADR    20 38
# 3          T4         dry,itchy skin         ADR    62 76
# 4          T5              Arthrotec        Drug    78 87
# 5          T6              arthritis     Disease  228 237
# 6          T8  empty stomach feeling         ADR    40 61
# 7          T9           glucoasamine        Drug  160 172
# 8         T10            chondroitin        Drug  173 184
# 9         T11                    MSM        Drug  189 192
# 10         T7                   pain     Symptom  299 303
# 11        T12                IB 1600        Drug  325 332
# 12        T13              tylenol 8        Drug  345 354
#   tag_number                              text entity_type  offsets
# 0         T1                    Blurred vision         ADR     0 14
# 1         T2                      Stomach ache         ADR    16 28
# 2         T3                   Water retention         ADR    30 45
# 3         T4                Throbbing headache         ADR    47 65
# 4         T5  Elevated my blood glucose levels         ADR    67 99
# 5         T6                           Vasotec        Drug  121 128
# 6         T7                         Glyburide        Drug  130 139
# 7         T8                           Avandia        Drug  141 148
#   tag_number                   text entity_type offsets
# 0         T1  severe abdonimal pain         ADR   10 31
# 1         T2        stool was black         ADR   45 60
# 2         T3      blood in my stool         ADR   82 99
# single positional indexer is out-of-bounds
#   tag_number          text entity_type  offsets
# 0         T2          pain     Symptom  196 200
# 1         T4   acid reflux     Symptom    50 61
# 2         T1  arthrotec 50        Drug  351 363
# 3         T3          pain     Symptom  428 432
# 4         T5          pain     Symptom  533 537
#   tag_number                           text entity_type  offsets
# 0         T1                 abdominal pain         ADR     0 14
# 1         T2                       headache         ADR    46 54
# 2         T3  general stomach upset feeling         ADR    56 85
# 3         T4                      Arthrotec        Drug  204 213
# 4         T5                  stomach pains         ADR  299 312
# 5         T6   constant soreness in abdomen         ADR    16 44
# 6         T7                       Celebrex        Drug  143 151
# 7         T8                          Vioxx        Drug  176 181
# 8         T9                         Lodine        Drug  188 194
#   tag_number       text entity_type offsets
# 0         T1       pain     Symptom   69 73
# 1         T2  heartburn         ADR    9 18
# single positional indexer is out-of-bounds
#   tag_number                   text entity_type          offsets
# 0         T1               diarrhea         ADR             6 14
# 1         T2  severe abdominal pain         ADR            16 37
# 2         T3               vomiting         ADR            79 87
# 3         T4              dizziness         ADR          100 109
# 4         T5                 nausea         ADR          111 117
# 5         T6              trembling         ADR            89 98
# 6         T7              Arthrotec        Drug          119 128
# 7         T8       menstrual cramps         ADR          149 165
# 8         T9            pain severe         ADR  180 184;191 197
# 9        T10   severe menstual pain         ADR          431 451
#   tag_number                text entity_type  offsets
# 0         T1     abdominal pains         ADR    19 34
# 1         T2        severe welts         ADR    36 48
# 2         T3    rapid heart beat         ADR  109 125
# 3         T4           headaches         ADR  130 139
# 4         T5  swelling of throat         ADR   89 107
#   tag_number            text entity_type offsets
# 0         T1  arthritic pain     Symptom   58 72
# single positional indexer is out-of-bounds
#   tag_number                    text entity_type  offsets
# 0         T1               Dizziness         ADR   91 100
# 1         T2               faintness         ADR  139 148
# 2         T3      Major stomach pain         ADR  200 218
# 3         T4      massive gas cramps         ADR  220 238
# 4         T5  bathroom with the runs         ADR  281 303
# 5         T7          disorientation         ADR  153 167
# 6         T8                bloating         ADR  243 251
# 7         T9                    sick         ADR  466 470
# 8         T6            heart attack     Finding  328 340
# 9        T10                  stroke     Finding  344 350
#   tag_number                    text entity_type  offsets
# 0         T1                diarrhea         ADR  268 276
# 1         T2              thumb pain     Symptom    37 47
# 2         T3               back pain     Symptom    74 83
# 3         T4  stomach hurt soooo bad         ADR  102 124
# 4         T5            stomach pain         ADR  237 249
# 5         T6      thumbs hurt so bad     Symptom  180 198
#   tag_number              text entity_type  offsets
# 0         T1  Abdominal cramps         ADR     0 16
# 1         T2        flatulence         ADR    18 28
# 2         T3       coccyx pain     Symptom  125 136
# 3         T4            cramps         ADR  145 151
# 4         T5            Cramps         ADR    45 51
# 5         T6          bloating         ADR    35 43
# 6         T7               gas         ADR    30 33
# 7         T8          bloating         ADR  156 164
#   tag_number             text entity_type offsets
# 0         T1  urine is bloody         ADR    3 18
# 1         T2     canker sores         ADR   31 43
# 2         T3         It hurts         ADR  92 100
# single positional indexer is out-of-bounds
#   tag_number                                               text entity_type  \
# 0         T1  little vaginal bleeding in spite of being meno...         ADR
# 1         T2                              back does feel better     Symptom
# 2         T3                                            Estrace        Drug
# 3         T4                                            Estrace        Drug
#
#    offsets
# 0   43 108
# 1  206 227
# 2  127 134
# 3  188 195
#   tag_number                text entity_type      offsets
# 0         T1      pain in my hip     Symptom  24 28;36 45
# 1         T2  hard on my stomach         ADR        58 76
# 2         T3    vaginal bleeding         ADR      122 138
# single positional indexer is out-of-bounds
#   tag_number             text entity_type  offsets
# 0         T1  aches and pains     Symptom  176 191
# 1         T2     acidophilous        Drug    34 46
# single positional indexer is out-of-bounds
#   tag_number                                   text entity_type offsets
# 0         T1  extended bleeding during menstruation         ADR    7 44
# 1         T2                              back pain     Symptom   60 69
# single positional indexer is out-of-bounds
#   tag_number                   text entity_type  offsets
# 0         T1  heavy menstral cycles         ADR    10 31
# 1         T2                fatigue         ADR    33 40
# 2         T3           slow healing         ADR    42 54
# 3         T4                   pain     Symptom  188 192
# ...
# 8         T9  genitals and lips excruciating         ADR  122 139;144 156
#   tag_number          text entity_type  offsets
# 0         T1      voltaren        Drug    45 53
# 1         T2      bruising     Symptom    84 92
# 2         T3  inflammation     Symptom  104 116
# single positional indexer is out-of-bounds
#   tag_number                text entity_type  offsets
# 0         T1               tired         ADR    18 23
# 1         T2     wanted to vomit         ADR    25 40
# 2         T3  hands and hip pain     Symptom  148 166
# single positional indexer is out-of-bounds
#   tag_number            text entity_type offsets
# 0         T1  Stomach cramps         ADR    0 14
# 1         T2        diarrhea         ADR   16 24
# 2         T3         fatigue         ADR   26 33
# single positional indexer is out-of-bounds
#   tag_number           text entity_type  offsets
# 0         T1    misoprostol        Drug  111 122
# 1         T2           pain     Symptom     8 12
# 2         T3  muscle spasms     Symptom    17 30
# single positional indexer is out-of-bounds
#    tag_number                text entity_type  offsets
# 0          T1        pruritus ani         ADR  228 240
# 1          T2    vaginal bleeding         ADR     7 23
# 2          T3  vaginal skin burns         ADR    31 49
# 3          T4         breast pain         ADR   94 105
# 4          T5            erithema         ADR  129 137
# 5          T6      skin is so dry         ADR  142 156
# 6          T7            sweating         ADR  194 202
# 7          T8            diarrhea         ADR  353 361
# 8          T9                pain     Symptom  504 508
# 9         T10    vaginal bleeding         ADR  526 542
# 10        T11            pruritus         ADR  553 561
# 11        T12          diclofenac        Drug  611 621
#   tag_number           text entity_type offsets
# 0         T1  stomach upset         ADR    0 13
# 1         T2    dehydration         ADR   26 37
# single positional indexer is out-of-bounds
#   tag_number            text entity_type offsets
# 0         T1        vomiting         ADR   46 54
# 1         T2  stomach cramps         ADR   11 25
# single positional indexer is out-of-bounds
#   tag_number              text entity_type offsets
# 0         T1  vaginal bleeding         ADR    7 23
# 1         T2          cramping         ADR   28 36
# single positional indexer is out-of-bounds
#   tag_number                    text entity_type          offsets
# 0         T1                  nausea         ADR          307 313
# 1         T2      heart was thumping         ADR          119 137
# 2         T3             chest pains         ADR          170 181
# 3         T4  pain in my kidney area         ADR          215 237
# 4         T5         pain in stomach         ADR  215 221;249 256
# 5         T6         skin irritation         ADR          318 333
# 6         T7                Volteren        Drug          375 383
#   tag_number                       text entity_type          offsets
# 0         T1                   wheezing         ADR            19 27
# 1         T2  skin rash back of my neck         ADR  246 255;263 278
# single positional indexer is out-of-bounds
#   tag_number               text entity_type  offsets
# 0         T1  slipped vertabrae     Disease     9 26
# 1         T2  degenerative disk     Disease    33 50
# 2         T3            Relafen        Drug  192 199
# 3         T4           vicodine        Drug  201 209
# 4         T5           flexeril        Drug  211 219
#   tag_number                     text entity_type  offsets
# 0         T1                 diarrhea         ADR  128 136
# 1         T2  chronic bone/joint pain     Symptom  283 306
# 2         T3                 Voltaren        Drug  439 447
# single positional indexer is out-of-bounds
#   tag_number            text entity_type offsets
# 0         T1  Stomach cramps         ADR    0 14
# single positional indexer is out-of-bounds
#   tag_number                    text entity_type  offsets
# 0         T1  tightness in my throat         ADR    49 71
# 1         T2           tingling eyes         ADR    73 86
# 2         T3            heart attack         ADR  241 253
# single positional indexer is out-of-bounds
#    tag_number              text entity_type  offsets
# 0          T1          voltaren        Drug  239 247
# 1          T2          voltaren        Drug  552 560
# 2          T3          celebrex        Drug     9 17
# 3          T4          voltaren        Drug    63 71
# 4          T5       wild dreams         ADR    77 88
# 5          T6  gurgling stomach         ADR   89 105
# 6          T7             tired         ADR  106 111
# 7          T8             moody         ADR  113 118
# 8          T9  high blood press         ADR  171 187
# 9         T10     heart stopped         ADR  136 149
# 10        T11      hypertension         ADR  283 295
# 11        T12         arthritis     Disease  325 334
# 12        T13     tylenol extra        Drug  307 320
# 13        T14          Voltaren        Drug  336 344
# 14        T15    arthritis pain     Symptom  417 431
# 15        T16           tagamet        Drug  462 469
#   tag_number      text entity_type offsets
# 0         T1    cramps         ADR     0 6
# 1         T2  diarreah         ADR    8 16
# single positional indexer is out-of-bounds
#   tag_number                                             text entity_type  \
# 0         T1                                 severe knee pain     Symptom
# 1         T2  I had trouble standing up from sitting position     Symptom
#
#    offsets
# 0  207 223
# 1  366 413
# single positional indexer is out-of-bounds
#   tag_number       text entity_type offsets
# 0         T1  dizziness         ADR     0 9
# 1         T2     nausea         ADR   31 37
# single positional indexer is out-of-bounds
#    tag_number              text entity_type  offsets
# 0          T1     mild headache         ADR  128 141
# 1          T2  abdominal cramps         ADR  214 230
# 2          T3          diarrhea         ADR  244 252
# 3          T4               gas         ADR  280 283
# 4          T5            nausea         ADR  388 394
# 5          T6         heartburn         ADR  400 409
# 6          T7      bad headache         ADR  360 372
# 7          T8          cramping         ADR  378 386
# 8          T9     mild cramping         ADR  295 308
# 9         T10          iubrofen        Drug  443 451
# 10        T11              pain     Symptom  569 573
# 11        T12          gurgling         ADR  285 293
#   tag_number              text entity_type offsets
# 0         T1          diarrhea         ADR    8 16
# 1         T2          vomiting         ADR   18 26
# 2         T3  extreme sweating         ADR   28 44
# 3         T4         dizzyness         ADR   46 55
# 4         T5         very weak         ADR   57 66
# 5         T6            chills         ADR   77 83
#    tag_number                          text entity_type  offsets
# 0          T1     edema of fingers and face         ADR    26 51
# 1          T2           shortness of breath         ADR   98 117
# 2          T3                      cramping         ADR  144 152
# 3          T4                      spotting         ADR  175 183
# 4          T5                      Voltaren        Drug  226 234
# 5          T6                  muscle spasm     Symptom  342 354
# 6          T7               short of breath         ADR  524 539
# 7          T8                      cramping         ADR  541 549
# 8          T9                       bloated         ADR  554 561
# 9         T10                    crabbiness         ADR  129 139
# 10        T11  Timing off for a true period         ADR  185 213
# 11        T12  face and fingers are swollen         ADR  486 514
#   tag_number                  text entity_type  offsets
# 0         T1             dizziness         ADR      0 9
# 1         T2               vertigo         ADR    10 17
# 2         T3         altered taste         ADR    19 32
# 3         T4                   gas         ADR    34 37
# 4         T5  blisters in my mouth         ADR    46 66
# 5         T6           itchy scalp         ADR    68 79
# 6         T7               vertigo         ADR  226 233
#   tag_number                text entity_type  offsets
# 0         T1  stomach discomfort         ADR     8 26
# 1         T2            Diarreha         ADR    28 36
# 2         T3              cramps         ADR    38 44
# 3         T4                 gas         ADR    46 49
# 4         T5            bloating         ADR    51 59
# 5         T6                pain         ADR  165 169
# 6         T7            diarreha         ADR  174 182
# 7         T8      kneejoin paint     Symptom  254 268
#   tag_number                      text entity_type  offsets
# 0         T1                  Voltaren        Drug    50 58
# 1         T2                  diarrhea         ADR  207 215
# 2         T3          chest discomfort         ADR  401 417
# 3         T4        abdominal pressure         ADR  428 446
# 4         T5                  prilosec        Drug  676 684
# 5         T6                      GERD     Disease  622 626
# 6         T7                  Voltaren        Drug  896 904
# 7         T8                        RX        Drug    96 98
# 8         T9  extreme abdominal issues         ADR  172 196
# Empty DataFrame
# Columns: [tag_number, text, entity_type, offsets]
# Index: []
# single positional indexer is out-of-bounds
#   tag_number                                 text entity_type  offsets
# 0         T1                                tired         ADR     7 12
# 1         T2                          blood clots         ADR    27 38
# 2         T3                             Voltaren        Drug    49 57
# 3         T4                               stroke         ADR  110 116
# 4         T5                             voltaren        Drug  301 309
# 5         T6                            back pain     Symptom  524 533
# 6         T7                              tylonol        Drug  548 555
# 7         T8  blood clots that traveled to my eye         ADR  125 160
# Empty DataFrame
# Columns: [tag_number, text, entity_type, offsets]
# Index: []
# single positional indexer is out-of-bounds
# Empty DataFrame
# Columns: [tag_number, text, entity_type, offsets]
# Index: []
# single positional indexer is out-of-bounds
#   tag_number                          text entity_type        offsets
# 0         T1                 stomach upset         ADR           7 20
# 1         T2      blood in bowel movements         ADR          22 46
# 2         T3                      bloating         ADR          48 56
# 3         T4                   inflamation     Symptom        125 136
# 4         T5  more limber Limbs and joints     Finding  109 120;80 96
# Empty DataFrame
# Columns: [tag_number, text, entity_type, offsets]
# Index: []
# single positional indexer is out-of-bounds
#   tag_number    text entity_type offsets
# 0         T2  bextra        Drug   25 31
# 1         T3   vioxx        Drug   18 23
# 2         T4   mobic        Drug   33 38
# 3         T5  ultram        Drug   43 49
# Empty DataFrame
# Columns: [tag_number, text, entity_type, offsets]
# Index: []
# single positional indexer is out-of-bounds
#   tag_number    text entity_type offsets
# 0         T1  drowsy         ADR   40 46
# single positional indexer is out-of-bounds
# Empty DataFrame
# Columns: [tag_number, text, entity_type, offsets]
# Index: []
# single positional indexer is out-of-bounds
#   tag_number                          text entity_type offsets
# 0         T1  taken its toll on my stomach         ADR    7 35
# single positional indexer is out-of-bounds
#   tag_number        text entity_type          offsets
# 0         T2  pains back     Symptom  192 197;199 203
# 1         T1       aches     Symptom          182 187
# single positional indexer is out-of-bounds
#   tag_number                      text entity_type  offsets
# 0         T1                  voltaren        Drug  202 210
# 1         T2                      gout     Symptom  248 252
# 2         T4        stomach discomfort         ADR    19 37
# 3         T3  liver and kidneys are ok     Symptom  385 409
#   tag_number        text entity_type offsets
# 0         T1  rise in bp     Symptom   41 51
# single positional indexer is out-of-bounds
#   tag_number       text entity_type  offsets
# 0         T1      dizzy         ADR     9 14
# 1         T2      silly         ADR    16 21
# 2         T3     sleepy         ADR    23 29
# 3         T4       high         ADR    53 57
# 4         T5  sleep aid         ADR  125 134
# 5         T6       pain     Symptom  153 157
#   tag_number             text entity_type  offsets
# 0         T1             rash         ADR    65 69
# 1         T2        dizziness         ADR  194 203
# 2         T3  bloated stomach         ADR  205 220
# 3         T4              gas         ADR  222 225
# 4         T5  muscle weakness         ADR  231 246
# 5         T6      kidney pain         ADR  275 286
# 6         T7         weakness         ADR  462 470
# 7         T8             rash         ADR  476 480
#   tag_number                              text entity_type          offsets
# 0         T1                   lower back pain     Symptom            40 55
# 1         T2  passing massive amounts of blood         ADR          182 214
# 2         T3                 ulcer lower bowel         ADR  364 369;376 387
# 3         T4                       Voltaren-XR        Drug            17 28
# 4         T5                          bleeding         ADR          256 264
#   tag_number                        text entity_type  offsets
# 0         T1                   Psychosis         ADR      0 9
# 1         T2               stomach upset         ADR    11 24
# 2         T3                     shaking         ADR    26 33
# 3         T4                    bi-polar     Disease   92 100
# 4         T5  recurrent stomach problems     Symptom  259 285
# 5         T6                    seroquel        Drug  394 402
# 6         T7                    bi-polar     Disease  425 433
# 7         T8                   ibuprofen        Drug  669 678
# 8         T9             mood stabilizer     Finding  179 194
#   tag_number           text entity_type  offsets
# 0         T1    blood clots         ADR  227 238
# 1         T2  upset stomach         ADR  281 294
# 2         T3         Asprin        Drug  300 306
# 3         T4        strokes         ADR  253 260
# 4         T5  heart attacks         ADR  265 278
#   tag_number    text entity_type offsets
# 0         T1  nausea         ADR     0 6
# 1         T2    pain     Symptom   13 17
# single positional indexer is out-of-bounds
#   tag_number          text entity_type         offsets
# 0         T1          pain     Symptom         142 146
# 1         T2   sore throat     Symptom         270 281
# 2         T3  hurts throat         ADR  111 116;98 104
# single positional indexer is out-of-bounds
#   tag_number                    text entity_type offsets
# 0         T1              stiff neck         ADR    0 10
# 1         T2  tightness in shoulders         ADR   12 34
# 2         T3             muscle pain         ADR   36 47
# single positional indexer is out-of-bounds
#   tag_number   text entity_type offsets
# 0         T1   pain     Symptom   17 21
# 1         T2  mobic        Drug   89 94
# single positional indexer is out-of-bounds
#    tag_number                           text entity_type      offsets
# 0          T1                         Zipsor        Drug        17 23
# 1         T11                      bone pain     Symptom  28 32;43 47
# 2          T2                     joint pain     Symptom  37 42;43 47
# 3          T3                          Lupus     Disease        64 69
# 4          T4                herniated discs     Disease       85 100
# 5          T5                        Vicodin        Drug      188 195
# 6         T12                         Zipsor        Drug      216 222
# 7          T6                     Lupus pain     Symptom      241 251
# 8          T7  pain from the herniated discs     Symptom      294 323
# 9         T10                    disc issues     Finding      397 408
# 10         T8                         Zipsor        Drug      528 534
# 11         T9                           pain     Symptom      540 544

# %%
import json

def save_to_jsonl(data, file_path):
    with open(file_path, 'w+') as f:
        for entry in data:
            f.write(json.dumps(entry) + '\n')

# %%
for file_original, file_text in zip(dir_list_original, dir_list_text):
    path_original = f'..\\data\\external\\cadec\\original\\{file_original}'
    path_text = f'..\\data\\external\\cadec\\text\\{file_text}'

    try:
        df_original = process_original_to_df(path_original)
        print(file_original)
        entities = create_list_of_entities(df_original)
        word_tags = create_datataset_of_word_tags(path_text, entities)

        output_json_file_path = f'..\\data\\processed\\word tags format\\{file_text}.jsonl'

        save_to_jsonl(word_tags, output_json_file_path)
    except IndexError as e:
        print(e)
# Out:
# ARTHROTEC.1.ann
# ARTHROTEC.2.ann
# ARTHROTEC.3.ann
# ARTHROTEC.4.ann
# ARTHROTEC.5.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.6.ann
# ARTHROTEC.7.ann
# ARTHROTEC.8.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.9.ann
# ARTHROTEC.10.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.11.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.12.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.13.ann
# ARTHROTEC.14.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.15.ann
# ARTHROTEC.16.ann
# ARTHROTEC.17.ann
# ARTHROTEC.18.ann
# ARTHROTEC.19.ann
# ARTHROTEC.20.ann
# ARTHROTEC.21.ann
# ARTHROTEC.22.ann
# ARTHROTEC.23.ann
# ARTHROTEC.24.ann
# ARTHROTEC.25.ann
# ARTHROTEC.26.ann
# ARTHROTEC.27.ann
# ARTHROTEC.28.ann
# ARTHROTEC.29.ann
# ARTHROTEC.30.ann
# ARTHROTEC.31.ann
# ARTHROTEC.32.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.33.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.34.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.35.ann
# ARTHROTEC.36.ann
# ARTHROTEC.37.ann
# ARTHROTEC.38.ann
# ARTHROTEC.39.ann
# ARTHROTEC.40.ann
# ARTHROTEC.41.ann
# ARTHROTEC.42.ann
# ARTHROTEC.43.ann
# ARTHROTEC.44.ann
# ARTHROTEC.45.ann
# ARTHROTEC.46.ann
# ARTHROTEC.47.ann
# ARTHROTEC.48.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.49.ann
# ARTHROTEC.50.ann
# ARTHROTEC.51.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.52.ann
# ARTHROTEC.53.ann
# ARTHROTEC.54.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.55.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.56.ann
# ARTHROTEC.57.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.58.ann
# ARTHROTEC.59.ann
# ARTHROTEC.60.ann
# ARTHROTEC.61.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.62.ann
# ARTHROTEC.63.ann
# ARTHROTEC.64.ann
# ARTHROTEC.65.ann
# ARTHROTEC.66.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.67.ann
# ARTHROTEC.68.ann
# ARTHROTEC.69.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.70.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.71.ann
# ARTHROTEC.72.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.73.ann
# ARTHROTEC.74.ann
# ARTHROTEC.75.ann
# ARTHROTEC.76.ann
# ARTHROTEC.77.ann
# ARTHROTEC.78.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.79.ann
# ARTHROTEC.80.ann
# ARTHROTEC.81.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.82.ann
# ARTHROTEC.83.ann
# ARTHROTEC.84.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.85.ann
# ARTHROTEC.86.ann
# ARTHROTEC.87.ann
# ARTHROTEC.88.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.89.ann
# ARTHROTEC.90.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.91.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.92.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.93.ann
# ARTHROTEC.94.ann
# ARTHROTEC.95.ann
# ARTHROTEC.96.ann
# ARTHROTEC.97.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.98.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.99.ann
# ARTHROTEC.100.ann
# ARTHROTEC.101.ann
# ARTHROTEC.102.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.103.ann
# ARTHROTEC.104.ann
# ARTHROTEC.105.ann
# ARTHROTEC.106.ann
# ARTHROTEC.107.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.108.ann
# ARTHROTEC.109.ann
# ARTHROTEC.110.ann
# ARTHROTEC.111.ann
# ARTHROTEC.112.ann
# ARTHROTEC.113.ann
# ARTHROTEC.114.ann
# ARTHROTEC.115.ann
# ARTHROTEC.116.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.117.ann
# ARTHROTEC.118.ann
# ARTHROTEC.119.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.120.ann
# ARTHROTEC.121.ann
# ARTHROTEC.122.ann
# ARTHROTEC.123.ann
# ARTHROTEC.124.ann
# ARTHROTEC.125.ann
# ARTHROTEC.126.ann
# ARTHROTEC.127.ann
# ARTHROTEC.128.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.129.ann
# ARTHROTEC.130.ann
# ARTHROTEC.131.ann
# ARTHROTEC.132.ann
# ARTHROTEC.133.ann
# ARTHROTEC.134.ann
# ARTHROTEC.135.ann
# ARTHROTEC.136.ann
# ARTHROTEC.137.ann
# ARTHROTEC.138.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.139.ann
# single positional indexer is out-of-bounds
# ARTHROTEC.140.ann
# ARTHROTEC.141.ann
# ARTHROTEC.142.ann
# ARTHROTEC.143.ann
# ARTHROTEC.144.ann
# ARTHROTEC.145.ann
# single positional indexer is out-of-bounds
# CAMBIA.1.ann
# single positional indexer is out-of-bounds
# CAMBIA.2.ann
# single positional indexer is out-of-bounds
# CAMBIA.3.ann
# CAMBIA.4.ann
# single positional indexer is out-of-bounds
# CATAFLAM.1.ann
# single positional indexer is out-of-bounds
# CATAFLAM.2.ann
# CATAFLAM.3.ann
# CATAFLAM.4.ann
# CATAFLAM.5.ann
# single positional indexer is out-of-bounds
# CATAFLAM.6.ann
# single positional indexer is out-of-bounds
# CATAFLAM.7.ann
# CATAFLAM.8.ann
# CATAFLAM.9.ann
# CATAFLAM.10.ann
# DICLOFENAC-POTASSIUM.1.ann
# single positional indexer is out-of-bounds
# DICLOFENAC-POTASSIUM.2.ann
# single positional indexer is out-of-bounds
# DICLOFENAC-POTASSIUM.3.ann
# DICLOFENAC-SODIUM.1.ann
# DICLOFENAC-SODIUM.2.ann
# DICLOFENAC-SODIUM.3.ann
# DICLOFENAC-SODIUM.4.ann
# single positional indexer is out-of-bounds
# DICLOFENAC-SODIUM.5.ann
# DICLOFENAC-SODIUM.6.ann
# DICLOFENAC-SODIUM.7.ann
# FLECTOR.1.ann
# LIPITOR.1.ann
# LIPITOR.2.ann
# single positional indexer is out-of-bounds
# LIPITOR.3.ann
# LIPITOR.4.ann
# single positional indexer is out-of-bounds
# LIPITOR.5.ann
# single positional indexer is out-of-bounds
# LIPITOR.6.ann
# LIPITOR.7.ann
# LIPITOR.8.ann
# LIPITOR.9.ann
# LIPITOR.10.ann
# LIPITOR.11.ann
# LIPITOR.12.ann
# LIPITOR.13.ann
# LIPITOR.14.ann
# LIPITOR.15.ann
# LIPITOR.16.ann
# single positional indexer is out-of-bounds
# LIPITOR.17.ann
# LIPITOR.18.ann
# LIPITOR.19.ann
# single positional indexer is out-of-bounds
# LIPITOR.20.ann
# LIPITOR.21.ann
# LIPITOR.574.ann
# LIPITOR.575.ann
# LIPITOR.576.ann
# LIPITOR.577.ann
# single positional indexer is out-of-bounds
# LIPITOR.578.ann
# LIPITOR.579.ann
# LIPITOR.580.ann
# single positional indexer is out-of-bounds
# LIPITOR.581.ann
# LIPITOR.582.ann
# LIPITOR.583.ann
# LIPITOR.584.ann
# LIPITOR.585.ann
# LIPITOR.586.ann
# LIPITOR.587.ann
# LIPITOR.588.ann
# LIPITOR.589.ann
# LIPITOR.590.ann
# LIPITOR.591.ann
# LIPITOR.592.ann
# LIPITOR.593.ann
# LIPITOR.594.ann
# single positional indexer is out-of-bounds
# LIPITOR.595.ann
# LIPITOR.596.ann
# LIPITOR.597.ann
# single positional indexer is out-of-bounds
# LIPITOR.598.ann
# LIPITOR.599.ann
# single positional indexer is out-of-bounds
# LIPITOR.600.ann
# single positional indexer is out-of-bounds
# LIPITOR.601.ann
# single positional indexer is out-of-bounds
# LIPITOR.602.ann
# LIPITOR.603.ann
# LIPITOR.604.ann
# LIPITOR.605.ann
# LIPITOR.606.ann
# LIPITOR.607.ann
# single positional indexer is out-of-bounds
# LIPITOR.608.ann
# single positional indexer is out-of-bounds
# LIPITOR.609.ann
# single positional indexer is out-of-bounds
# LIPITOR.610.ann
# LIPITOR.611.ann
# LIPITOR.612.ann
# LIPITOR.613.ann
# LIPITOR.614.ann
# LIPITOR.615.ann
# single positional indexer is out-of-bounds
# LIPITOR.616.ann
# LIPITOR.617.ann
# LIPITOR.618.ann
# single positional indexer is out-of-bounds
# LIPITOR.619.ann
# LIPITOR.620.ann
# LIPITOR.621.ann
# LIPITOR.622.ann
# LIPITOR.623.ann
# LIPITOR.624.ann
# single positional indexer is out-of-bounds
# LIPITOR.625.ann
# single positional indexer is out-of-bounds
# LIPITOR.626.ann
# LIPITOR.627.ann
# LIPITOR.628.ann
# single positional indexer is out-of-bounds
# LIPITOR.629.ann
# LIPITOR.630.ann
# single positional indexer is out-of-bounds
# LIPITOR.631.ann
# LIPITOR.632.ann
# single positional indexer is out-of-bounds
# LIPITOR.633.ann
# single positional indexer is out-of-bounds
# LIPITOR.634.ann
# single positional indexer is out-of-bounds
# LIPITOR.635.ann
# LIPITOR.636.ann
# single positional indexer is out-of-bounds
# LIPITOR.637.ann
# single positional indexer is out-of-bounds
# LIPITOR.638.ann
# single positional indexer is out-of-bounds
# LIPITOR.639.ann
# LIPITOR.640.ann
# LIPITOR.641.ann
# LIPITOR.642.ann
# LIPITOR.643.ann
# LIPITOR.644.ann
# single positional indexer is out-of-bounds
# LIPITOR.645.ann
# single positional indexer is out-of-bounds
# LIPITOR.646.ann
# LIPITOR.647.ann
# single positional indexer is out-of-bounds
# LIPITOR.648.ann
# LIPITOR.649.ann
# single positional indexer is out-of-bounds
# LIPITOR.650.ann
# LIPITOR.651.ann
# single positional indexer is out-of-bounds
# LIPITOR.652.ann
# LIPITOR.653.ann
# LIPITOR.654.ann
# LIPITOR.655.ann
# single positional indexer is out-of-bounds
# LIPITOR.656.ann
# LIPITOR.657.ann
# single positional indexer is out-of-bounds
# LIPITOR.841.ann
# LIPITOR.842.ann
# LIPITOR.843.ann
# single positional indexer is out-of-bounds
# LIPITOR.844.ann
# LIPITOR.845.ann
# LIPITOR.846.ann
# single positional indexer is out-of-bounds
# LIPITOR.847.ann
# LIPITOR.848.ann
# LIPITOR.849.ann
# LIPITOR.850.ann
# LIPITOR.851.ann
# LIPITOR.852.ann
# single positional indexer is out-of-bounds
# LIPITOR.853.ann
# LIPITOR.854.ann
# LIPITOR.855.ann
# single positional indexer is out-of-bounds
# LIPITOR.856.ann
# LIPITOR.857.ann
# single positional indexer is out-of-bounds
# LIPITOR.858.ann
# LIPITOR.859.ann
# LIPITOR.860.ann
# LIPITOR.861.ann
# LIPITOR.862.ann
# single positional indexer is out-of-bounds
# LIPITOR.863.ann
# single positional indexer is out-of-bounds
# LIPITOR.864.ann
# single positional indexer is out-of-bounds
# LIPITOR.865.ann
# LIPITOR.866.ann
# LIPITOR.867.ann
# LIPITOR.868.ann
# LIPITOR.869.ann
# single positional indexer is out-of-bounds
# LIPITOR.870.ann
# LIPITOR.871.ann
# single positional indexer is out-of-bounds
# LIPITOR.872.ann
# LIPITOR.873.ann
# LIPITOR.874.ann
# LIPITOR.875.ann
# LIPITOR.876.ann
# single positional indexer is out-of-bounds
# LIPITOR.877.ann
# single positional indexer is out-of-bounds
# LIPITOR.878.ann
# LIPITOR.879.ann
# single positional indexer is out-of-bounds
# LIPITOR.880.ann
# single positional indexer is out-of-bounds
# LIPITOR.881.ann
# single positional indexer is out-of-bounds
# LIPITOR.882.ann
# LIPITOR.883.ann
# single positional indexer is out-of-bounds
# LIPITOR.884.ann
# LIPITOR.885.ann
# LIPITOR.886.ann
# LIPITOR.887.ann
# LIPITOR.888.ann
# LIPITOR.889.ann
# single positional indexer is out-of-bounds
# LIPITOR.890.ann
# LIPITOR.891.ann
# LIPITOR.892.ann
# single positional indexer is out-of-bounds
# LIPITOR.893.ann
# LIPITOR.894.ann
# LIPITOR.895.ann
# single positional indexer is out-of-bounds
# LIPITOR.896.ann
# LIPITOR.897.ann
# LIPITOR.898.ann
# LIPITOR.899.ann
# LIPITOR.900.ann
# single positional indexer is out-of-bounds
# LIPITOR.901.ann
# LIPITOR.902.ann
# LIPITOR.903.ann
# LIPITOR.904.ann
# LIPITOR.905.ann
# LIPITOR.906.ann
# LIPITOR.907.ann
# single positional indexer is out-of-bounds
# LIPITOR.908.ann
# LIPITOR.909.ann
# LIPITOR.910.ann
# single positional indexer is out-of-bounds
# LIPITOR.911.ann
# LIPITOR.912.ann
# LIPITOR.913.ann
# LIPITOR.914.ann
# LIPITOR.915.ann
# single positional indexer is out-of-bounds
# LIPITOR.916.ann
# LIPITOR.917.ann
# LIPITOR.918.ann
# single positional indexer is out-of-bounds
# LIPITOR.919.ann
# single positional indexer is out-of-bounds
# LIPITOR.920.ann
# LIPITOR.921.ann
# single positional indexer is out-of-bounds
# LIPITOR.922.ann
# LIPITOR.923.ann
# LIPITOR.924.ann
# single positional indexer is out-of-bounds
# LIPITOR.925.ann
# LIPITOR.926.ann
# LIPITOR.927.ann
# LIPITOR.928.ann
# LIPITOR.929.ann
# single positional indexer is out-of-bounds
# LIPITOR.930.ann
# single positional indexer is out-of-bounds
# LIPITOR.931.ann
# LIPITOR.932.ann
# LIPITOR.933.ann
# single positional indexer is out-of-bounds
# LIPITOR.934.ann
# LIPITOR.935.ann
# LIPITOR.936.ann
# LIPITOR.937.ann
# LIPITOR.938.ann
# single positional indexer is out-of-bounds
# LIPITOR.939.ann
# LIPITOR.940.ann
# single positional indexer is out-of-bounds
# LIPITOR.941.ann
# LIPITOR.942.ann
# single positional indexer is out-of-bounds
# LIPITOR.943.ann
# LIPITOR.944.ann
# LIPITOR.945.ann
# LIPITOR.946.ann
# single positional indexer is out-of-bounds
# LIPITOR.947.ann
# LIPITOR.948.ann
# single positional indexer is out-of-bounds
# LIPITOR.949.ann
# single positional indexer is out-of-bounds
# LIPITOR.950.ann
# LIPITOR.951.ann
# LIPITOR.952.ann
# LIPITOR.953.ann
# single positional indexer is out-of-bounds
# LIPITOR.954.ann
# LIPITOR.955.ann
# LIPITOR.956.ann
# LIPITOR.957.ann
# LIPITOR.958.ann
# single positional indexer is out-of-bounds
# LIPITOR.959.ann
# LIPITOR.960.ann
# single positional indexer is out-of-bounds
# LIPITOR.961.ann
# LIPITOR.962.ann
# single positional indexer is out-of-bounds
# LIPITOR.963.ann
# single positional indexer is out-of-bounds
# LIPITOR.964.ann
# single positional indexer is out-of-bounds
# LIPITOR.965.ann
# LIPITOR.966.ann
# LIPITOR.967.ann
# LIPITOR.968.ann
# LIPITOR.969.ann
# LIPITOR.970.ann
# LIPITOR.971.ann
# LIPITOR.972.ann
# LIPITOR.973.ann
# LIPITOR.974.ann
# LIPITOR.975.ann
# LIPITOR.976.ann
# LIPITOR.977.ann
# LIPITOR.978.ann
# LIPITOR.979.ann
# LIPITOR.980.ann
# LIPITOR.981.ann
# LIPITOR.982.ann
# LIPITOR.983.ann
# LIPITOR.984.ann
# LIPITOR.985.ann
# single positional indexer is out-of-bounds
# LIPITOR.986.ann
# single positional indexer is out-of-bounds
# LIPITOR.987.ann
# LIPITOR.988.ann
# single positional indexer is out-of-bounds
# LIPITOR.989.ann
# LIPITOR.990.ann
# LIPITOR.991.ann
# LIPITOR.992.ann
# LIPITOR.993.ann
# single positional indexer is out-of-bounds
# LIPITOR.994.ann
# LIPITOR.995.ann
# LIPITOR.996.ann
# LIPITOR.997.ann
# LIPITOR.998.ann
# single positional indexer is out-of-bounds
# LIPITOR.999.ann
# single positional indexer is out-of-bounds
# LIPITOR.1000.ann
# PENNSAID.1.ann
# PENNSAID.2.ann
# single positional indexer is out-of-bounds
# PENNSAID.3.ann
# PENNSAID.4.ann
# single positional indexer is out-of-bounds
# SOLARAZE.1.ann
# single positional indexer is out-of-bounds
# SOLARAZE.2.ann
# SOLARAZE.3.ann
# single positional indexer is out-of-bounds
# VOLTAREN.1.ann
# single positional indexer is out-of-bounds
# VOLTAREN.2.ann
# single positional indexer is out-of-bounds
# VOLTAREN.3.ann
# VOLTAREN.4.ann
# VOLTAREN.5.ann
# VOLTAREN.6.ann
# VOLTAREN.7.ann
# VOLTAREN.8.ann
# VOLTAREN.9.ann
# VOLTAREN.10.ann
# single positional indexer is out-of-bounds
# VOLTAREN.11.ann
# VOLTAREN.12.ann
# VOLTAREN.13.ann
# VOLTAREN.14.ann
# single positional indexer is out-of-bounds
# VOLTAREN.15.ann
# single positional indexer is out-of-bounds
# VOLTAREN.16.ann
# single positional indexer is out-of-bounds
# VOLTAREN.17.ann
# VOLTAREN.18.ann
# VOLTAREN.19.ann
# single positional indexer is out-of-bounds
# VOLTAREN.20.ann
# VOLTAREN.21.ann
# VOLTAREN.22.ann
# single positional indexer is out-of-bounds
# VOLTAREN.23.ann
# VOLTAREN.24.ann
# single positional indexer is out-of-bounds
# VOLTAREN.25.ann
# VOLTAREN.26.ann
# single positional indexer is out-of-bounds
# VOLTAREN.27.ann
# single positional indexer is out-of-bounds
# VOLTAREN.28.ann
# single positional indexer is out-of-bounds
# VOLTAREN.29.ann
# single positional indexer is out-of-bounds
# VOLTAREN.30.ann
# VOLTAREN.31.ann
# single positional indexer is out-of-bounds
# VOLTAREN.32.ann
# single positional indexer is out-of-bounds
# VOLTAREN.33.ann
# single positional indexer is out-of-bounds
# VOLTAREN.34.ann
# VOLTAREN.35.ann
# single positional indexer is out-of-bounds
# VOLTAREN.36.ann
# VOLTAREN.37.ann
# single positional indexer is out-of-bounds
# VOLTAREN.38.ann
# single positional indexer is out-of-bounds
# VOLTAREN.39.ann
# single positional indexer is out-of-bounds
# VOLTAREN.40.ann
# VOLTAREN.41.ann
# single positional indexer is out-of-bounds
# VOLTAREN.42.ann
# single positional indexer is out-of-bounds
# VOLTAREN.43.ann
# single positional indexer is out-of-bounds
# VOLTAREN.44.ann
# VOLTAREN.45.ann
# VOLTAREN.46.ann
# VOLTAREN-XR.1.ann
# VOLTAREN-XR.2.ann
# VOLTAREN-XR.3.ann
# VOLTAREN-XR.4.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.5.ann
# VOLTAREN-XR.6.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.7.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.8.ann
# VOLTAREN-XR.9.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.10.ann
# VOLTAREN-XR.11.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.12.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.13.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.14.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.15.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.16.ann
# VOLTAREN-XR.17.ann
# single positional indexer is out-of-bounds
# VOLTAREN-XR.18.ann
# VOLTAREN-XR.19.ann
# VOLTAREN-XR.20.ann
# VOLTAREN-XR.21.ann
# VOLTAREN-XR.22.ann
# ZIPSOR.1.ann
# single positional indexer is out-of-bounds
# ZIPSOR.2.ann
# single positional indexer is out-of-bounds
# ZIPSOR.3.ann
# single positional indexer is out-of-bounds
# ZIPSOR.4.ann
# single positional indexer is out-of-bounds
# ZIPSOR.5.ann
